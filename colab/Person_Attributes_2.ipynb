# %% [markdown]
# <a href="https://colab.research.google.com/github/mashruravi/eip-hvc/blob/master/colab/Person_Attributes_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# !unzip -q "/content/gdrive/My Drive/hvc_data.zip"
# !cp /content/gdrive/My\ Drive/hvc_encoded_3.csv /content/
# `hvc_encoded.csv` and `resized` should be available
# %ls
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive
# gdrive/  hvc_annotations.csv  hvc_encoded_3.csv  resized/  sample_data/

# %%
import pandas as pd

# %%
df = pd.read_csv('hvc_encoded_3.csv')
df.head()
# Out:
#       image_path  gender_female  ...  bodypose_Front-Frontish  bodypose_Side
# 0  resized/1.jpg              0  ...                        1              0
# 1  resized/2.jpg              1  ...                        1              0
# 2  resized/3.jpg              0  ...                        1              0
# 3  resized/4.jpg              0  ...                        1              0
# 4  resized/5.jpg              1  ...                        1              0
#
# [5 rows x 28 columns]

# %%
from sklearn.model_selection import train_test_split
train_df, val_df = train_test_split(df, test_size=0.15)

# %%
train_df.shape, val_df.shape
# Out:
# ((11537, 28), (2036, 28))

# %%
# Columns for one-hot encoded labels
def get_columns_by_prefix(prefix):
  return [col for col in df if col.startswith(prefix)]

_gender_columns = get_columns_by_prefix('gender')
_qual_columns_ = get_columns_by_prefix('qual')
_age_columns_ = get_columns_by_prefix('age')
_weight_columns_ = get_columns_by_prefix('weight')
_bag_columns_ = get_columns_by_prefix('bag')
_footwear_columns_ = get_columns_by_prefix('footwear')
_emotion_columns_ = get_columns_by_prefix('emotion')
_bodypose_columns_ = get_columns_by_prefix('bodypose')

# %%
import tensorflow
print(tensorflow.__version__)
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# 1.15.0

# %%
import keras
import numpy as np
import cv2
from __future__ import division

class DataGenerator(tensorflow.keras.utils.Sequence):
  
  def __init__(self, df, batch_size=32, shuffle=True):
    self.df = df
    self.batch_size = batch_size
    self.shuffle = shuffle

  def __len__(self):
    return int(np.ceil(self.df.shape[0] / self.batch_size))

  def __getitem__(self, index):
    """ return X=224,224,3,batch_size and y=num_classes,batch_size"""
    batch_slice = slice(index * self.batch_size, (index + 1) * self.batch_size)
    items = self.df.iloc[batch_slice]
    images = np.stack([cv2.imread(item['image_path']) for _, item in items.iterrows()])
    images = images/255
    target = {
        'gender_output': items[_gender_columns].values,
        'imagequality_output': items[_qual_columns_].values,
        'age_output': items[_age_columns_].values,
        'weight_output': items[_weight_columns_].values,
        'bag_output': items[_bag_columns_].values,
        'footwear_output': items[_footwear_columns_].values,
        'emotion_output': items[_emotion_columns_].values,
        'bodypose_output': items[_bodypose_columns_].values
    }
    return images, target

  def on_epoch_end(self):
    """Shuffle data after each epoch"""
    if self.shuffle == True:
      self.df = self.df.sample(frac=1).reset_index(drop=True)
# Out:
# Using TensorFlow backend.

# %%
BATCH_SIZE=16
train_gen = DataGenerator(train_df, batch_size=BATCH_SIZE, shuffle=True)
valid_gen = DataGenerator(val_df, batch_size=BATCH_SIZE, shuffle=False)

# %%
images, targets = next(iter(train_gen))

# %%
def get_unit_count(value_output):
  if (len(value_output.shape) > 1):
    return value_output.shape[1]
  else:
    return 1
num_units = { k.split("_output")[0]: get_unit_count(v) for k, v in targets.items() }
num_units
# Out:
# {'age': 5,
#  'bag': 3,
#  'bodypose': 3,
#  'emotion': 4,
#  'footwear': 3,
#  'gender': 2,
#  'imagequality': 3,
#  'weight': 4}

# %%
from __future__ import division

import six
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    Input,
    Activation,
    Dense,
    Flatten,
    Dropout
)
from tensorflow.keras.layers import (
    Conv2D,
    MaxPooling2D,
    AveragePooling2D,
    GlobalAveragePooling2D
)
from tensorflow.keras.layers import add
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.regularizers import l2
from tensorflow.keras import backend as K


weight_decay = 0.005

def initial_conv(input):
    x = Conv2D(100, (3, 3), padding='same', kernel_initializer='he_normal',
                      kernel_regularizer=l2(weight_decay),
                      use_bias=False, name="conv_init")(input)

    channel_axis = -1

    x = BatchNormalization(axis=channel_axis, momentum=0.1, epsilon=1e-5, gamma_initializer='uniform', name="BN_init")(x)
    x = Activation('relu')(x)
    return x


def expand_conv(idx, init, base, k, strides=(1, 1)):
    x = Conv2D(base * k, (3, 3), padding='same', strides=strides, kernel_initializer='he_normal',
                      kernel_regularizer=l2(weight_decay),
                      use_bias=False, name="conv_expand_"+str(idx)+"_1")(init)

    channel_axis = 1 if K.image_data_format() == "channels_first" else -1

    x = BatchNormalization(axis=channel_axis, momentum=0.1, epsilon=1e-5, gamma_initializer='uniform', name="BN_expand"+str(idx))(x)
    x = Activation('relu')(x)

    x = Conv2D(base * k, (3, 3), padding='same', kernel_initializer='he_normal',
                      kernel_regularizer=l2(weight_decay),
                      use_bias=False, name="conv_expand_"+str(idx)+"_2")(x)

    skip = Conv2D(base * k, (1, 1), padding='same', strides=strides, kernel_initializer='he_normal',
                      kernel_regularizer=l2(weight_decay),
                      use_bias=False, name="conv_expand_"+str(idx)+"_3")(init)

    m = add([x, skip])

    return m


def conv1_block(idx, input, k=1, dropout=0.0):
    init = input

    channel_axis = -1

    x = BatchNormalization(axis=channel_axis, momentum=0.1, epsilon=1e-5, gamma_initializer='uniform', name="BN1_"+str(idx)+"_1")(input)
    x = Activation('relu')(x)
    x = Conv2D(16 * k, (3, 3), padding='same', kernel_initializer='he_normal',
                      kernel_regularizer=l2(weight_decay),
                      use_bias=False, name="conv1_"+str(idx)+"_1")(x)

    if dropout > 0.0: x = Dropout(rate=dropout)(x)

    x = BatchNormalization(axis=channel_axis, momentum=0.1, epsilon=1e-5, gamma_initializer='uniform', name="BN1_"+str(idx)+"_2")(x)
    x = Activation('relu')(x)
    x = Conv2D(16 * k, (3, 3), padding='same', kernel_initializer='he_normal',
                      kernel_regularizer=l2(weight_decay),
                      use_bias=False, name="conv1_"+str(idx)+"_2")(x)

    m = add([init, x])
    return m

def conv2_block(idx, input, k=1, dropout=0.0):
    init = input

    channel_axis = -1

    x = BatchNormalization(axis=channel_axis, momentum=0.1, epsilon=1e-5, gamma_initializer='uniform', name="BN2_"+str(idx)+"_1")(input)
    x = Activation('relu')(x)
    x = Conv2D(32 * k, (3, 3), padding='same', kernel_initializer='he_normal',
                      kernel_regularizer=l2(weight_decay),
                      use_bias=False, name="conv2_"+str(idx)+"_1")(x)

    if dropout > 0.0: x = Dropout(rate=dropout)(x)

    x = BatchNormalization(axis=channel_axis, momentum=0.1, epsilon=1e-5, gamma_initializer='uniform', name="BN2_"+str(idx)+"_2")(x)
    x = Activation('relu')(x)
    x = Conv2D(32 * k, (3, 3), padding='same', kernel_initializer='he_normal',
                      kernel_regularizer=l2(weight_decay),
                      use_bias=False,name="conv2_"+str(idx)+"_2")(x)

    m = add([init, x])
    return m

def conv3_block(idx, input, k=1, dropout=0.0):
    init = input

    channel_axis = -1

    x = BatchNormalization(axis=channel_axis, momentum=0.1, epsilon=1e-5, gamma_initializer='uniform', name="BN3_"+str(idx)+"_1")(input)
    x = Activation('relu')(x)
    x = Conv2D(64 * k, (3, 3), padding='same', kernel_initializer='he_normal',
                      kernel_regularizer=l2(weight_decay),
                      use_bias=False, name="conv3_"+str(idx)+"_1")(x)

    if dropout > 0.0: x = Dropout(rate=dropout)(x)

    x = BatchNormalization(axis=channel_axis, momentum=0.1, epsilon=1e-5, gamma_initializer='uniform', name="BN3_"+str(idx)+"_2")(x)
    x = Activation('relu')(x)
    x = Conv2D(64 * k, (3, 3), padding='same', kernel_initializer='he_normal',
                      kernel_regularizer=l2(weight_decay),
                      use_bias=False, name="conv3_"+str(idx)+"_2")(x)

    m = add([init, x])
    return m

def create_wide_residual_network(input_dim, nb_classes=100, N=2, k=1, dropout=0.0, verbose=1):
    """
    Creates a Wide Residual Network with specified parameters

    :param input: Input Keras object
    :param nb_classes: Number of output classes
    :param N: Depth of the network. Compute N = (n - 4) / 6.
              Example : For a depth of 16, n = 16, N = (16 - 4) / 6 = 2
              Example2: For a depth of 28, n = 28, N = (28 - 4) / 6 = 4
              Example3: For a depth of 40, n = 40, N = (40 - 4) / 6 = 6
    :param k: Width of the network.
    :param dropout: Adds dropout if value is greater than 0.0
    :param verbose: Debug info to describe created WRN
    :return:
    """
    channel_axis = 1 if K.image_data_format() == "channels_first" else -1

    ip = Input(shape=input_dim)

    x = initial_conv(ip)
    nb_conv = 4

    x = expand_conv(1, x, 16, k)
    nb_conv += 2

    for i in range(N - 1):
        x = conv1_block(i, x, k, dropout)
        nb_conv += 2

    x = BatchNormalization(axis=channel_axis, momentum=0.1, epsilon=1e-5, gamma_initializer='uniform', name="BN_1")(x)
    x = Activation('relu')(x)

    x = expand_conv(2, x, 32, k, strides=(2, 2))
    nb_conv += 2

    for i in range(N - 1):
        x = conv2_block(i, x, k, dropout)
        nb_conv += 2

    x = BatchNormalization(axis=channel_axis, momentum=0.1, epsilon=1e-5, gamma_initializer='uniform', name="BN_2")(x)
    x = Activation('relu')(x)

    x = expand_conv(3, x, 64, k, strides=(2, 2))
    nb_conv += 2

    for i in range(N - 1):
        x = conv3_block(i, x, k, dropout)
        nb_conv += 2

    x = BatchNormalization(axis=channel_axis, momentum=0.1, epsilon=1e-5, gamma_initializer='uniform', name="BN_3")(x)
    x = Activation('relu')(x)

    # x = Conv2D(nb_classes, (1,1), padding="same", name="conv_final")(x)
    # x = GlobalAveragePooling2D(name="GAP")(x)
    # x = Activation("softmax")(x)

    # model = Model(ip, x)

    # if verbose: print("Wide Residual Network-%d-%d created." % (nb_conv, k))
    # return model

# %%
from tensorflow.keras.layers import Input, Conv2D, Dense, Flatten
from tensorflow.keras.models import Model
# from tensorflow.keras.optimizers import SGD

def get_backbone(input_layer, num_filters=32):

  N = 1
  k = 1
  dropout = 0.0
  verbose = 1

  channel_axis = 1 if K.image_data_format() == "channels_first" else -1

  ip = input_layer

  x = initial_conv(ip)
  nb_conv = 4

  x = expand_conv(1, x, 16, k)
  nb_conv += 2

  for i in range(N - 1):
      x = conv1_block(i, x, k, dropout)
      nb_conv += 2

  x = BatchNormalization(axis=channel_axis, momentum=0.1, epsilon=1e-5, gamma_initializer='uniform', name="BN_1")(x)
  x = Activation('relu')(x)

  x = expand_conv(2, x, 32, k, strides=(2, 2))
  nb_conv += 2

  for i in range(N - 1):
      x = conv2_block(i, x, k, dropout)
      nb_conv += 2

  x = BatchNormalization(axis=channel_axis, momentum=0.1, epsilon=1e-5, gamma_initializer='uniform', name="BN_2")(x)
  x = Activation('relu')(x)

  x = expand_conv(3, x, 64, k, strides=(2, 2))
  nb_conv += 2

  for i in range(N - 1):
      x = conv3_block(i, x, k, dropout)
      nb_conv += 2

  x = BatchNormalization(axis=channel_axis, momentum=0.1, epsilon=1e-5, gamma_initializer='uniform', name="BN_3")(x)
  x = Activation('relu')(x)
  return x

def get_neck(input_layer):
  x = Flatten()(input_layer)
  x = Dense(64, activation='relu')(x)
  x = Dense(32, activation='relu')(x)
  x = Dense(16, activation='relu')(x)
  return x

def get_head(name, input_layer):
  return Dense(num_units[name], activation='softmax', name=f'{name}_output')(input_layer)

def make_model():

  input = Input(shape=(224, 224, 3))

  backbone = get_backbone(input)
  backbone = Flatten()(backbone)
  backbone = Dense(512, activation='relu')(backbone)

  # neck = get_neck(backbone)

  # heads
  age = get_head('age', get_neck(backbone))
  bag = get_head('bag', get_neck(backbone))
  bodypose = get_head('bodypose', get_neck(backbone))
  emotion = get_head('emotion', get_neck(backbone))
  footwear = get_head('footwear', get_neck(backbone))
  gender = get_head('gender', get_neck(backbone))
  imagequality = get_head('imagequality', get_neck(backbone))
  weight = get_head('weight', get_neck(backbone))

  model = Model(
      inputs = input,
      outputs = [age, bag, bodypose, emotion, footwear, gender, imagequality, weight]
  )

  return model

# %%
import os

model = make_model()

model.compile(
    optimizer='SGD',
    loss={
        'gender_output': 'categorical_crossentropy',
        'imagequality_output': 'categorical_crossentropy',
        'age_output': 'categorical_crossentropy',
        'weight_output': 'categorical_crossentropy',
        'bag_output': 'categorical_crossentropy',
        'footwear_output': 'categorical_crossentropy',
        'emotion_output': 'categorical_crossentropy',
        'bodypose_output': 'categorical_crossentropy'
    },
    metrics=["accuracy"]
)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/initializers.py:119: calling RandomUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv_init (Conv2D)              (None, 224, 224, 100 2700        input_1[0][0]
# __________________________________________________________________________________________________
# BN_init (BatchNormalization)    (None, 224, 224, 100 400         conv_init[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 224, 224, 100 0           BN_init[0][0]
# __________________________________________________________________________________________________
# conv_expand_1_1 (Conv2D)        (None, 224, 224, 16) 14400       activation[0][0]
# __________________________________________________________________________________________________
# BN_expand1 (BatchNormalization) (None, 224, 224, 16) 64          conv_expand_1_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 224, 224, 16) 0           BN_expand1[0][0]
# __________________________________________________________________________________________________
# conv_expand_1_2 (Conv2D)        (None, 224, 224, 16) 2304        activation_1[0][0]
# __________________________________________________________________________________________________
# conv_expand_1_3 (Conv2D)        (None, 224, 224, 16) 1600        activation[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 224, 224, 16) 0           conv_expand_1_2[0][0]
#                                                                  conv_expand_1_3[0][0]
# __________________________________________________________________________________________________
# BN_1 (BatchNormalization)       (None, 224, 224, 16) 64          add[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 224, 224, 16) 0           BN_1[0][0]
# __________________________________________________________________________________________________
# conv_expand_2_1 (Conv2D)        (None, 112, 112, 32) 4608        activation_2[0][0]
# __________________________________________________________________________________________________
# BN_expand2 (BatchNormalization) (None, 112, 112, 32) 128         conv_expand_2_1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 112, 112, 32) 0           BN_expand2[0][0]
# __________________________________________________________________________________________________
# conv_expand_2_2 (Conv2D)        (None, 112, 112, 32) 9216        activation_3[0][0]
# __________________________________________________________________________________________________
# conv_expand_2_3 (Conv2D)        (None, 112, 112, 32) 512         activation_2[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 112, 112, 32) 0           conv_expand_2_2[0][0]
#                                                                  conv_expand_2_3[0][0]
# __________________________________________________________________________________________________
# BN_2 (BatchNormalization)       (None, 112, 112, 32) 128         add_1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 112, 112, 32) 0           BN_2[0][0]
# __________________________________________________________________________________________________
# conv_expand_3_1 (Conv2D)        (None, 56, 56, 64)   18432       activation_4[0][0]
# __________________________________________________________________________________________________
# BN_expand3 (BatchNormalization) (None, 56, 56, 64)   256         conv_expand_3_1[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 56, 56, 64)   0           BN_expand3[0][0]
# __________________________________________________________________________________________________
# conv_expand_3_2 (Conv2D)        (None, 56, 56, 64)   36864       activation_5[0][0]
# __________________________________________________________________________________________________
# conv_expand_3_3 (Conv2D)        (None, 56, 56, 64)   2048        activation_4[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 56, 56, 64)   0           conv_expand_3_2[0][0]
#                                                                  conv_expand_3_3[0][0]
# __________________________________________________________________________________________________
# BN_3 (BatchNormalization)       (None, 56, 56, 64)   256         add_2[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 56, 56, 64)   0           BN_3[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 200704)       0           activation_6[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 512)          102760960   flatten[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 512)          0           dense[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 512)          0           dense[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 512)          0           dense[0][0]
# __________________________________________________________________________________________________
# flatten_4 (Flatten)             (None, 512)          0           dense[0][0]
# __________________________________________________________________________________________________
# flatten_5 (Flatten)             (None, 512)          0           dense[0][0]
# __________________________________________________________________________________________________
# flatten_6 (Flatten)             (None, 512)          0           dense[0][0]
# __________________________________________________________________________________________________
# flatten_7 (Flatten)             (None, 512)          0           dense[0][0]
# __________________________________________________________________________________________________
# flatten_8 (Flatten)             (None, 512)          0           dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 64)           32832       flatten_1[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 64)           32832       flatten_2[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 64)           32832       flatten_3[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 64)           32832       flatten_4[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 64)           32832       flatten_5[0][0]
# __________________________________________________________________________________________________
# dense_16 (Dense)                (None, 64)           32832       flatten_6[0][0]
# __________________________________________________________________________________________________
# dense_19 (Dense)                (None, 64)           32832       flatten_7[0][0]
# __________________________________________________________________________________________________
# dense_22 (Dense)                (None, 64)           32832       flatten_8[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 32)           2080        dense_1[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 32)           2080        dense_4[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 32)           2080        dense_7[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 32)           2080        dense_10[0][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, 32)           2080        dense_13[0][0]
# __________________________________________________________________________________________________
# dense_17 (Dense)                (None, 32)           2080        dense_16[0][0]
# __________________________________________________________________________________________________
# dense_20 (Dense)                (None, 32)           2080        dense_19[0][0]
# __________________________________________________________________________________________________
# dense_23 (Dense)                (None, 32)           2080        dense_22[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 16)           528         dense_2[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 16)           528         dense_5[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 16)           528         dense_8[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 16)           528         dense_11[0][0]
# __________________________________________________________________________________________________
# dense_15 (Dense)                (None, 16)           528         dense_14[0][0]
# __________________________________________________________________________________________________
# dense_18 (Dense)                (None, 16)           528         dense_17[0][0]
# __________________________________________________________________________________________________
# dense_21 (Dense)                (None, 16)           528         dense_20[0][0]
# __________________________________________________________________________________________________
# dense_24 (Dense)                (None, 16)           528         dense_23[0][0]
# __________________________________________________________________________________________________
# age_output (Dense)              (None, 5)            85          dense_3[0][0]
# __________________________________________________________________________________________________
# bag_output (Dense)              (None, 3)            51          dense_6[0][0]
# __________________________________________________________________________________________________
# bodypose_output (Dense)         (None, 3)            51          dense_9[0][0]
# __________________________________________________________________________________________________
# emotion_output (Dense)          (None, 4)            68          dense_12[0][0]
# __________________________________________________________________________________________________
# footwear_output (Dense)         (None, 3)            51          dense_15[0][0]
# __________________________________________________________________________________________________
# gender_output (Dense)           (None, 2)            34          dense_18[0][0]
# __________________________________________________________________________________________________
# imagequality_output (Dense)     (None, 3)            51          dense_21[0][0]
# __________________________________________________________________________________________________
# weight_output (Dense)           (None, 4)            68          dense_24[0][0]
# ==================================================================================================
# Total params: 103,138,919
# Trainable params: 103,138,271
# Non-trainable params: 648
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.callbacks import *

class CyclicLR(Callback):
    """This callback implements a cyclical learning rate policy (CLR).
    The method cycles the learning rate between two boundaries with
    some constant frequency, as detailed in this paper (https://arxiv.org/abs/1506.01186).
    The amplitude of the cycle can be scaled on a per-iteration or 
    per-cycle basis.
    This class has three built-in policies, as put forth in the paper.
    "triangular":
        A basic triangular cycle w/ no amplitude scaling.
    "triangular2":
        A basic triangular cycle that scales initial amplitude by half each cycle.
    "exp_range":
        A cycle that scales initial amplitude by gamma**(cycle iterations) at each 
        cycle iteration.
    For more detail, please see paper.
    
    # Example
        ```python
            clr = CyclicLR(base_lr=0.001, max_lr=0.006,
                                step_size=2000., mode='triangular')
            model.fit(X_train, Y_train, callbacks=[clr])
        ```
    
    Class also supports custom scaling functions:
        ```python
            clr_fn = lambda x: 0.5*(1+np.sin(x*np.pi/2.))
            clr = CyclicLR(base_lr=0.001, max_lr=0.006,
                                step_size=2000., scale_fn=clr_fn,
                                scale_mode='cycle')
            model.fit(X_train, Y_train, callbacks=[clr])
        ```    
    # Arguments
        base_lr: initial learning rate which is the
            lower boundary in the cycle.
        max_lr: upper boundary in the cycle. Functionally,
            it defines the cycle amplitude (max_lr - base_lr).
            The lr at any cycle is the sum of base_lr
            and some scaling of the amplitude; therefore 
            max_lr may not actually be reached depending on
            scaling function.
        step_size: number of training iterations per
            half cycle. Authors suggest setting step_size
            2-8 x training iterations in epoch.
        mode: one of {triangular, triangular2, exp_range}.
            Default 'triangular'.
            Values correspond to policies detailed above.
            If scale_fn is not None, this argument is ignored.
        gamma: constant in 'exp_range' scaling function:
            gamma**(cycle iterations)
        scale_fn: Custom scaling policy defined by a single
            argument lambda function, where 
            0 <= scale_fn(x) <= 1 for all x >= 0.
            mode paramater is ignored 
        scale_mode: {'cycle', 'iterations'}.
            Defines whether scale_fn is evaluated on 
            cycle number or cycle iterations (training
            iterations since start of cycle). Default is 'cycle'.
    """

    def __init__(self, base_lr=0.001, max_lr=0.006, step_size=2000., mode='triangular',
                 gamma=1., scale_fn=None, scale_mode='cycle'):
        super(CyclicLR, self).__init__()

        self.base_lr = base_lr
        self.max_lr = max_lr
        self.step_size = step_size
        self.mode = mode
        self.gamma = gamma
        if scale_fn == None:
            if self.mode == 'triangular':
                self.scale_fn = lambda x: 1.
                self.scale_mode = 'cycle'
            elif self.mode == 'triangular2':
                self.scale_fn = lambda x: 1/(2.**(x-1))
                self.scale_mode = 'cycle'
            elif self.mode == 'exp_range':
                self.scale_fn = lambda x: gamma**(x)
                self.scale_mode = 'iterations'
        else:
            self.scale_fn = scale_fn
            self.scale_mode = scale_mode
        self.clr_iterations = 0.
        self.trn_iterations = 0.
        self.history = {}

        self._reset()

    def _reset(self, new_base_lr=None, new_max_lr=None,
               new_step_size=None):
        """Resets cycle iterations.
        Optional boundary/step size adjustment.
        """
        if new_base_lr != None:
            self.base_lr = new_base_lr
        if new_max_lr != None:
            self.max_lr = new_max_lr
        if new_step_size != None:
            self.step_size = new_step_size
        self.clr_iterations = 0.
        
    def clr(self):
        cycle = np.floor(1+self.clr_iterations/(2*self.step_size))
        x = np.abs(self.clr_iterations/self.step_size - 2*cycle + 1)
        if self.scale_mode == 'cycle':
            return self.base_lr + (self.max_lr-self.base_lr)*np.maximum(0, (1-x))*self.scale_fn(cycle)
        else:
            return self.base_lr + (self.max_lr-self.base_lr)*np.maximum(0, (1-x))*self.scale_fn(self.clr_iterations)
        
    def on_train_begin(self, logs={}):
        logs = logs or {}

        if self.clr_iterations == 0:
            K.set_value(self.model.optimizer.lr, self.base_lr)
        else:
            K.set_value(self.model.optimizer.lr, self.clr())        
            
    def on_batch_end(self, epoch, logs=None):
        
        logs = logs or {}
        self.trn_iterations += 1
        self.clr_iterations += 1

        self.history.setdefault('lr', []).append(K.get_value(self.model.optimizer.lr))
        self.history.setdefault('iterations', []).append(self.trn_iterations)

        for k, v in logs.items():
            self.history.setdefault(k, []).append(v)
        
        K.set_value(self.model.optimizer.lr, self.clr())

# %%
clr = CyclicLR(base_lr=1e-12, max_lr=.1, step_size=14421)

# %%
history = model.fit_generator(
    generator=train_gen,
    # validation_data=valid_gen,
    epochs=20,
    callbacks=[clr]
)
# Out:
# Epoch 1/20
# 722/722 [==============================] - 88s 122ms/step - loss: 12.5420 - age_output_loss: 1.4751 - bag_output_loss: 0.9548 - bodypose_output_loss: 0.9555 - emotion_output_loss: 0.9960 - footwear_output_loss: 0.9860 - gender_output_loss: 0.6666 - imagequality_output_loss: 1.0150 - weight_output_loss: 1.0713 - age_output_acc: 0.3378 - bag_output_acc: 0.5494 - bodypose_output_acc: 0.6117 - emotion_output_acc: 0.7062 - footwear_output_acc: 0.5343 - gender_output_acc: 0.5756 - imagequality_output_acc: 0.5357 - weight_output_acc: 0.6223
# Epoch 2/20
# 722/722 [==============================] - 79s 109ms/step - loss: 11.6311 - age_output_loss: 1.4060 - bag_output_loss: 0.9043 - bodypose_output_loss: 0.8426 - emotion_output_loss: 0.9100 - footwear_output_loss: 0.8829 - gender_output_loss: 0.6114 - imagequality_output_loss: 0.9814 - weight_output_loss: 0.9766 - age_output_acc: 0.3997 - bag_output_acc: 0.5628 - bodypose_output_acc: 0.6357 - emotion_output_acc: 0.7086 - footwear_output_acc: 0.5970 - gender_output_acc: 0.6508 - imagequality_output_acc: 0.5541 - weight_output_acc: 0.6372
# Epoch 3/20
# 722/722 [==============================] - 78s 109ms/step - loss: 1.0330 - age_output_loss: 0.0978 - bag_output_loss: 0.0712 - bodypose_output_loss: 0.0579 - emotion_output_loss: 0.0579 - footwear_output_loss: 0.0605 - gender_output_loss: 0.0439 - imagequality_output_loss: 0.0673 - weight_output_loss: 0.0700 - age_output_acc: 0.9704 - bag_output_acc: 0.9772 - bodypose_output_acc: 0.9821 - emotion_output_acc: 0.9822 - footwear_output_acc: 0.9801 - gender_output_acc: 0.9854 - imagequality_output_acc: 0.9772 - weight_output_acc: 0.9788
# Epoch 20/20
# 722/722 [==============================] - 78s 109ms/step - loss: 1.0131 - age_output_loss: 0.0882 - bag_output_loss: 0.0644 - bodypose_output_loss: 0.0484 - emotion_output_loss: 0.0595 - footwear_output_loss: 0.0552 - gender_output_loss: 0.0368 - imagequality_output_loss: 0.0675 - weight_output_loss: 0.0687 - age_output_acc: 0.9726 - bag_output_acc: 0.9789 - bodypose_output_acc: 0.9847 - emotion_output_acc: 0.9812 - footwear_output_acc: 0.9805 - gender_output_acc: 0.9875 - imagequality_output_acc: 0.9800 - weight_output_acc: 0.9801

# %%
lr = clr.history['lr']
loss = clr.history['loss']

losses = [
  clr.history['age_output_loss'],
  clr.history['bag_output_loss'],
  clr.history['bodypose_output_loss'],
  clr.history['emotion_output_loss'],
  clr.history['footwear_output_loss'],
  clr.history['gender_output_loss'],
  clr.history['imagequality_output_loss'],
  clr.history['weight_output_loss']
]

import matplotlib.pyplot as plt

print('LR range vs iteration')
plt.plot(range(len(lr)), lr)
plt.show()

print('Loss vs LR')
items=300
plt.plot(lr[:items], loss[:items])
plt.show()

print('Individual Loss vs LR')
for loss in losses:
  plt.plot(lr, loss)
plt.show()
# Out:
# LR range vs iteration
# Loss vs LR
# Individual Loss vs LR

# %%
clr = CyclicLR(base_lr=0.0005, max_lr=0.001, step_size=5000)
history = model.fit_generator(
    generator=train_gen,
    validation_data=valid_gen,
    epochs=20,
    callbacks=[clr]
)
# Out:
# Epoch 1/20
# 721/722 [============================>.] - ETA: 0s - loss: 0.8759 - age_output_loss: 0.0593 - bag_output_loss: 0.0366 - bodypose_output_loss: 0.0520 - emotion_output_loss: 0.0361 - footwear_output_loss: 0.0378 - gender_output_loss: 0.0216 - imagequality_output_loss: 0.0400 - weight_output_loss: 0.0443 - age_output_acc: 0.9817 - bag_output_acc: 0.9885 - bodypose_output_acc: 0.9832 - emotion_output_acc: 0.9894 - footwear_output_acc: 0.9890 - gender_output_acc: 0.9940 - imagequality_output_acc: 0.9873 - weight_output_acc: 0.9879Epoch 1/20
# 722/722 [==============================] - 85s 118ms/step - loss: 0.8756 - age_output_loss: 0.0594 - bag_output_loss: 0.0365 - bodypose_output_loss: 0.0519 - emotion_output_loss: 0.0361 - footwear_output_loss: 0.0378 - gender_output_loss: 0.0216 - imagequality_output_loss: 0.0400 - weight_output_loss: 0.0442 - age_output_acc: 0.9816 - bag_output_acc: 0.9885 - bodypose_output_acc: 0.9832 - emotion_output_acc: 0.9894 - footwear_output_acc: 0.9890 - gender_output_acc: 0.9940 - imagequality_output_acc: 0.9873 - weight_output_acc: 0.9880 - val_loss: 14.8306 - val_age_output_
.1153 - val_gender_output_loss: 1.2206 - val_imagequality_output_loss: 2.6149 - val_weight_output_loss: 2.2689 - val_age_output_acc: 0.3242 - val_bag_output_acc: 0.5339 - val_bodypose_output_acc: 0.6395 - val_emotion_output_acc: 0.6449 - val_footwear_output_acc: 0.5413 - val_gender_output_acc: 0.6940 - val_imagequality_output_acc: 0.4779 - val_weight_output_acc: 0.5565
# Epoch 16/20
# 721/722 [============================>.] - ETA: 0s - loss: 0.4902 - age_output_loss: 0.0031 - bag_output_loss: 0.0034 - bodypose_output_loss: 0.0018 - emotion_output_loss: 0.0030 - footwear_output_loss: 0.0035 - gender_output_loss: 0.0021 - imagequality_output_loss: 0.0033 - weight_output_loss: 0.0025 - age_output_acc: 0.9997 - bag_output_acc: 0.9995 - bodypose_output_acc: 0.9998 - emotion_output_acc: 0.9995 - footwear_output_acc: 0.9993 - gender_output_acc: 0.9997 - imagequality_output_acc: 0.9997 - weight_output_acc: 0.9997Epoch 1/20
# 722/722 [==============================] - 85s 118ms/step - loss: 0.4902 - age_output_loss: 0.0031 - bag_output_loss: 0.0034 - bodypose_output_loss: 0.0018 - emotion_output_loss: 0.0030 - footwear_output_loss: 0.0035 - gender_output_loss: 0.0021 - imagequality_output_loss: 0.0033 - weight_output_loss: 0.0025 - age_output_acc: 0.9997 - bag_output_acc: 0.9995 - bodypose_output_acc: 0.9998 - emotion_output_acc: 0.9995 - footwear_output_acc: 0.9993 - gender_output_acc: 0.9997 - imagequality_output_acc: 0.9997 - weight_output_acc: 0.9997 - val_loss: 17.8438 - val_age_output_loss: 3.2485 - val_bag_output_loss: 2.0833 - val_bodypose_output_loss: 1.5705 - val_emotion_output_loss: 2.2798 - val_footwear_output_loss: 2.0993 - val_gender_output_loss: 1.2282 - val_imagequality_output_loss: 2.5917 - val_weight_output_loss: 2.2772 - val_age_output_acc: 0.3256 - val_bag_output_acc: 0.5334 - val_bodypose_output_acc: 0.6361 - val_emotion_output_acc: 0.6528 - val_footwear_output_acc: 0.5373 - val_gender_output_acc: 0.6896 - val_imagequality_output_acc: 0.4710 - val_weight_output_acc: 0.5589
# Epoch 17/20
# 711/722 [============================>.] - ETA: 1s - loss: 0.4843 - age_output_loss: 0.0028 - bag_output_loss: 0.0031 - bodypose_output_loss: 0.0018 - emotion_output_loss: 0.0028 - footwear_output_loss: 0.0032 - gender_output_loss: 0.0018 - imagequality_output_loss: 0.0032 - weight_output_loss: 0.0025 - age_output_acc: 0.9996 - bag_output_acc: 0.9995 - bodypose_output_acc: 0.9998 - emotion_output_acc: 0.9997 - footwear_output_acc: 0.9993 - gender_output_acc: 0.9997 - imagequality_output_acc: 0.9996 - weight_output_acc: 0.9996
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-f367f0cabc0c> in <module>()
#       4     validation_data=valid_gen,
#       5     epochs=20,
# ----> 6     callbacks=[clr]
#       7 )
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1294         shuffle=shuffle,
#    1295         initial_epoch=initial_epoch,
# -> 1296         steps_name='steps_per_epoch')
#    1297
#    1298   def evaluate_generator(self,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/training_generator.py in model_iteration(model, data, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch, mode, batch_size, steps_name, **kwargs)
#     263
#     264       is_deferred = not model._is_compiled
# --> 265       batch_outs = batch_function(*batch_data)
#     266       if not isinstance(batch_outs, list):
#     267         batch_outs = [batch_outs]
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight, reset_metrics)
#    1015       self._update_sample_weight_modes(sample_weights=sample_weights)
#    1016       self._make_train_function()
# -> 1017       outputs = self.train_function(ins)  # pylint: disable=not-callable
#    1018
#    1019     if reset_metrics:
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/backend.py in __call__(self, inputs)
#    3474
#    3475     fetched = self._callable_fn(*array_vals,
# -> 3476                                 run_metadata=self.run_metadata)
#    3477     self._call_fetch_callbacks(fetched[-len(self._fetches):])
#    3478     output_structure = nest.pack_sequence_as(
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py in __call__(self, *args, **kwargs)
#    1470         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1471                                                self._handle, args,
# -> 1472                                                run_metadata_ptr)
#    1473         if run_metadata:
#    1474           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:
