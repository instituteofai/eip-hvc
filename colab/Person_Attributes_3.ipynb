# %% [markdown]
# <a href="https://colab.research.google.com/github/mashruravi/eip-hvc/blob/master/colab/Person_Attributes_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# !unzip -q "/content/gdrive/My Drive/hvc_data.zip"
# !cp /content/gdrive/My\ Drive/hvc_encoded_3.csv /content/
# `hvc_encoded.csv` and `resized` should be available
# %ls
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive
# gdrive/  hvc_annotations.csv  hvc_encoded_3.csv  resized/  sample_data/

# %%
import pandas as pd

# %%
df = pd.read_csv('hvc_encoded_3.csv')
df.head()
# Out:
#       image_path  gender_female  ...  bodypose_Front-Frontish  bodypose_Side
# 0  resized/1.jpg              0  ...                        1              0
# 1  resized/2.jpg              1  ...                        1              0
# 2  resized/3.jpg              0  ...                        1              0
# 3  resized/4.jpg              0  ...                        1              0
# 4  resized/5.jpg              1  ...                        1              0
#
# [5 rows x 28 columns]

# %%
from sklearn.model_selection import train_test_split
train_df, val_df = train_test_split(df, test_size=0.15)

# %%
train_df.shape, val_df.shape
# Out:
# ((11537, 28), (2036, 28))

# %%
# Columns for one-hot encoded labels
def get_columns_by_prefix(prefix):
  return [col for col in df if col.startswith(prefix)]

_gender_columns = get_columns_by_prefix('gender')
_qual_columns_ = get_columns_by_prefix('qual')
_age_columns_ = get_columns_by_prefix('age')
_weight_columns_ = get_columns_by_prefix('weight')
_bag_columns_ = get_columns_by_prefix('bag')
_footwear_columns_ = get_columns_by_prefix('footwear')
_emotion_columns_ = get_columns_by_prefix('emotion')
_bodypose_columns_ = get_columns_by_prefix('bodypose')

# %%
import tensorflow
print(tensorflow.__version__)
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# 1.15.0

# %%
import keras
import numpy as np
import cv2
from __future__ import division

class DataGenerator(tensorflow.keras.utils.Sequence):
  
  def __init__(self, df, batch_size=32, shuffle=True):
    self.df = df
    self.batch_size = batch_size
    self.shuffle = shuffle

  def __len__(self):
    return int(np.ceil(self.df.shape[0] / self.batch_size))

  def __getitem__(self, index):
    """ return X=224,224,3,batch_size and y=num_classes,batch_size"""
    batch_slice = slice(index * self.batch_size, (index + 1) * self.batch_size)
    items = self.df.iloc[batch_slice]
    images = np.stack([cv2.imread(item['image_path']) for _, item in items.iterrows()])
    images = images/255
    target = {
        'gender_output': items[_gender_columns].values,
        'imagequality_output': items[_qual_columns_].values,
        'age_output': items[_age_columns_].values,
        'weight_output': items[_weight_columns_].values,
        'bag_output': items[_bag_columns_].values,
        'footwear_output': items[_footwear_columns_].values,
        'emotion_output': items[_emotion_columns_].values,
        'bodypose_output': items[_bodypose_columns_].values
    }
    return images, target

  def on_epoch_end(self):
    """Shuffle data after each epoch"""
    if self.shuffle == True:
      self.df = self.df.sample(frac=1).reset_index(drop=True)
# Out:
# Using TensorFlow backend.

# %%
BATCH_SIZE=16
train_gen = DataGenerator(train_df, batch_size=BATCH_SIZE, shuffle=True)
valid_gen = DataGenerator(val_df, batch_size=BATCH_SIZE, shuffle=False)

# %%
images, targets = next(iter(train_gen))

# %%
def get_unit_count(value_output):
  if (len(value_output.shape) > 1):
    return value_output.shape[1]
  else:
    return 1
num_units = { k.split("_output")[0]: get_unit_count(v) for k, v in targets.items() }
num_units
# Out:
# {'age': 5,
#  'bag': 3,
#  'bodypose': 3,
#  'emotion': 4,
#  'footwear': 3,
#  'gender': 2,
#  'imagequality': 3,
#  'weight': 4}

# %%
tensorflow.reset_default_graph()

# %%
from __future__ import division

import six
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    Input,
    Activation,
    Dense,
    Flatten,
    Dropout
)
from tensorflow.keras.layers import (
    Conv2D,
    MaxPooling2D,
    AveragePooling2D,
    GlobalAveragePooling2D
)
from tensorflow.keras.layers import add
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.regularizers import l2
from tensorflow.keras import backend as K


weight_decay = 0.005

def initial_conv(input, i):
    x = Conv2D(100, (3, 3), padding='same', kernel_initializer='he_normal',
                      kernel_regularizer=l2(weight_decay),
                      use_bias=False, name=f"conv_init_{i}")(input)

    channel_axis = -1

    x = BatchNormalization(axis=channel_axis, momentum=0.1, epsilon=1e-5, gamma_initializer='uniform', name=f"BN_init_{i}")(x)
    x = Activation('relu')(x)
    return x


def expand_conv(idx, init, base, k, strides=(1, 1)):
    x = Conv2D(base * k, (3, 3), padding='same', strides=strides, kernel_initializer='he_normal',
                      kernel_regularizer=l2(weight_decay),
                      use_bias=False, name="conv_expand_"+str(idx)+"_1")(init)

    channel_axis = 1 if K.image_data_format() == "channels_first" else -1

    x = BatchNormalization(axis=channel_axis, momentum=0.1, epsilon=1e-5, gamma_initializer='uniform', name="BN_expand"+str(idx))(x)
    x = Activation('relu')(x)

    x = Conv2D(base * k, (3, 3), padding='same', kernel_initializer='he_normal',
                      kernel_regularizer=l2(weight_decay),
                      use_bias=False, name="conv_expand_"+str(idx)+"_2")(x)

    skip = Conv2D(base * k, (1, 1), padding='same', strides=strides, kernel_initializer='he_normal',
                      kernel_regularizer=l2(weight_decay),
                      use_bias=False, name="conv_expand_"+str(idx)+"_3")(init)

    m = add([x, skip])

    return m


def conv1_block(idx, input, k=1, dropout=0.0):
    init = input

    channel_axis = -1

    x = BatchNormalization(axis=channel_axis, momentum=0.1, epsilon=1e-5, gamma_initializer='uniform', name="BN1_"+str(idx)+"_1")(input)
    x = Activation('relu')(x)
    x = Conv2D(16 * k, (3, 3), padding='same', kernel_initializer='he_normal',
                      kernel_regularizer=l2(weight_decay),
                      use_bias=False, name="conv1_"+str(idx)+"_1")(x)

    if dropout > 0.0: x = Dropout(rate=dropout)(x)

    x = BatchNormalization(axis=channel_axis, momentum=0.1, epsilon=1e-5, gamma_initializer='uniform', name="BN1_"+str(idx)+"_2")(x)
    x = Activation('relu')(x)
    x = Conv2D(16 * k, (3, 3), padding='same', kernel_initializer='he_normal',
                      kernel_regularizer=l2(weight_decay),
                      use_bias=False, name="conv1_"+str(idx)+"_2")(x)

    m = add([init, x])
    return m

def conv2_block(idx, input, k=1, dropout=0.0):
    init = input

    channel_axis = -1

    x = BatchNormalization(axis=channel_axis, momentum=0.1, epsilon=1e-5, gamma_initializer='uniform', name="BN2_"+str(idx)+"_1")(input)
    x = Activation('relu')(x)
    x = Conv2D(32 * k, (3, 3), padding='same', kernel_initializer='he_normal',
                      kernel_regularizer=l2(weight_decay),
                      use_bias=False, name="conv2_"+str(idx)+"_1")(x)

    if dropout > 0.0: x = Dropout(rate=dropout)(x)

    x = BatchNormalization(axis=channel_axis, momentum=0.1, epsilon=1e-5, gamma_initializer='uniform', name="BN2_"+str(idx)+"_2")(x)
    x = Activation('relu')(x)
    x = Conv2D(32 * k, (3, 3), padding='same', kernel_initializer='he_normal',
                      kernel_regularizer=l2(weight_decay),
                      use_bias=False,name="conv2_"+str(idx)+"_2")(x)

    m = add([init, x])
    return m

def conv3_block(idx, input, k=1, dropout=0.0):
    init = input

    channel_axis = -1

    x = BatchNormalization(axis=channel_axis, momentum=0.1, epsilon=1e-5, gamma_initializer='uniform', name="BN3_"+str(idx)+"_1")(input)
    x = Activation('relu')(x)
    x = Conv2D(64 * k, (3, 3), padding='same', kernel_initializer='he_normal',
                      kernel_regularizer=l2(weight_decay),
                      use_bias=False, name="conv3_"+str(idx)+"_1")(x)

    if dropout > 0.0: x = Dropout(rate=dropout)(x)

    x = BatchNormalization(axis=channel_axis, momentum=0.1, epsilon=1e-5, gamma_initializer='uniform', name="BN3_"+str(idx)+"_2")(x)
    x = Activation('relu')(x)
    x = Conv2D(64 * k, (3, 3), padding='same', kernel_initializer='he_normal',
                      kernel_regularizer=l2(weight_decay),
                      use_bias=False, name="conv3_"+str(idx)+"_2")(x)

    m = add([init, x])
    return m

def create_wide_residual_network(input_layer, N=2, k=1, dropout=0.0, verbose=1, index=0):
    """
    Creates a Wide Residual Network with specified parameters

    :param input: Input Keras object
    :param nb_classes: Number of output classes
    :param N: Depth of the network. Compute N = (n - 4) / 6.
              Example : For a depth of 16, n = 16, N = (16 - 4) / 6 = 2
              Example2: For a depth of 28, n = 28, N = (28 - 4) / 6 = 4
              Example3: For a depth of 40, n = 40, N = (40 - 4) / 6 = 6
    :param k: Width of the network.
    :param dropout: Adds dropout if value is greater than 0.0
    :param verbose: Debug info to describe created WRN
    :return:
    """
    channel_axis = 1 if K.image_data_format() == "channels_first" else -1

    ip = input_layer

    x = initial_conv(ip, index)
    nb_conv = 4

    x = expand_conv(f"{index}_1", x, 16, k)
    nb_conv += 2

    for i in range(N - 1):
        x = conv1_block(f"{index}_i", x, k, dropout)
        nb_conv += 2

    x = BatchNormalization(axis=channel_axis, momentum=0.1, epsilon=1e-5, gamma_initializer='uniform', name=f"BN_{index}_1")(x)
    x = Activation('relu')(x)

    x = expand_conv(f"{index}_2", x, 32, k, strides=(2, 2))
    nb_conv += 2

    for i in range(N - 1):
        x = conv2_block(f"{index}_i", x, k, dropout)
        nb_conv += 2

    x = BatchNormalization(axis=channel_axis, momentum=0.1, epsilon=1e-5, gamma_initializer='uniform', name=f"BN_{index}_2")(x)
    x = Activation('relu')(x)

    x = expand_conv(f"{index}_3", x, 64, k, strides=(2, 2))
    nb_conv += 2

    for i in range(N - 1):
        x = conv3_block(f"{index}_i", x, k, dropout)
        nb_conv += 2

    x = BatchNormalization(axis=channel_axis, momentum=0.1, epsilon=1e-5, gamma_initializer='uniform', name=f"BN_{index}_3")(x)
    x = Activation('relu')(x)

    return x

    # x = Conv2D(nb_classes, (1,1), padding="same", name="conv_final")(x)
    # x = GlobalAveragePooling2D(name="GAP")(x)
    # x = Activation("softmax")(x)

    # model = Model(ip, x)

    # if verbose: print("Wide Residual Network-%d-%d created." % (nb_conv, k))
    # return model

# %%
from tensorflow.keras.layers import Input, Conv2D, Dense, Flatten
from tensorflow.keras.models import Model
# from tensorflow.keras.optimizers import SGD

def get_backbone(input_layer, num_filters=32):
  return create_wide_residual_network(input_layer, N=1, k=1, dropout=0.0, verbose=1, index=0)

def get_neck(input_layer, index):
  x = create_wide_residual_network(input_layer, N=1, k=1, dropout=0.0, verbose=1, index=index)
  x = Flatten()(x)
  x = Dense(64, activation='relu')(x)
  x = Dense(32, activation='relu')(x)
  x = Dense(16, activation='relu')(x)
  return x

def get_head(name, input_layer):
  return Dense(num_units[name], activation='softmax', name=f'{name}_output')(input_layer)

def make_model():

  input = Input(shape=(224, 224, 3))

  backbone = get_backbone(input)

  # neck = get_neck(backbone)

  # heads
  age = get_head('age', get_neck(backbone, 1))
  bag = get_head('bag', get_neck(backbone, 2))
  bodypose = get_head('bodypose', get_neck(backbone, 3))
  emotion = get_head('emotion', get_neck(backbone, 4))
  footwear = get_head('footwear', get_neck(backbone, 5))
  gender = get_head('gender', get_neck(backbone, 6))
  imagequality = get_head('imagequality', get_neck(backbone, 7))
  weight = get_head('weight', get_neck(backbone, 8))

  model = Model(
      inputs = input,
      outputs = [age, bag, bodypose, emotion, footwear, gender, imagequality, weight]
  )

  return model

# %%
import os

model = make_model()

model.compile(
    optimizer='SGD',
    loss={
        'gender_output': 'categorical_crossentropy',
        'imagequality_output': 'categorical_crossentropy',
        'age_output': 'categorical_crossentropy',
        'weight_output': 'categorical_crossentropy',
        'bag_output': 'categorical_crossentropy',
        'footwear_output': 'categorical_crossentropy',
        'emotion_output': 'categorical_crossentropy',
        'bodypose_output': 'categorical_crossentropy'
    },
    metrics=["accuracy"]
)

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv_init_0 (Conv2D)            (None, 224, 224, 100 2700        input_2[0][0]
# __________________________________________________________________________________________________
# BN_init_0 (BatchNormalization)  (None, 224, 224, 100 400         conv_init_0[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 224, 224, 100 0           BN_init_0[0][0]
# __________________________________________________________________________________________________
# conv_expand_0_1_1 (Conv2D)      (None, 224, 224, 16) 14400       activation_63[0][0]
# __________________________________________________________________________________________________
# BN_expand0_1 (BatchNormalizatio (None, 224, 224, 16) 64          conv_expand_0_1_1[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 224, 224, 16) 0           BN_expand0_1[0][0]
# __________________________________________________________________________________________________
# conv_expand_0_1_2 (Conv2D)      (None, 224, 224, 16) 2304        activation_64[0][0]
# __________________________________________________________________________________________________
# conv_expand_0_1_3 (Conv2D)      (None, 224, 224, 16) 1600        activation_63[0][0]
# __________________________________________________________________________________________________
# add_27 (Add)                    (None, 224, 224, 16) 0           conv_expand_0_1_2[0][0]
#                                                                  conv_expand_0_1_3[0][0]
# __________________________________________________________________________________________________
# BN_0_1 (BatchNormalization)     (None, 224, 224, 16) 64          add_27[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 224, 224, 16) 0           BN_0_1[0][0]
# __________________________________________________________________________________________________
# conv_expand_0_2_1 (Conv2D)      (None, 112, 112, 32) 4608        activation_65[0][0]
# __________________________________________________________________________________________________
# BN_expand0_2 (BatchNormalizatio (None, 112, 112, 32) 128         conv_expand_0_2_1[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 112, 112, 32) 0           BN_expand0_2[0][0]
# __________________________________________________________________________________________________
# conv_expand_0_2_2 (Conv2D)      (None, 112, 112, 32) 9216        activation_66[0][0]
# __________________________________________________________________________________________________
# conv_expand_0_2_3 (Conv2D)      (None, 112, 112, 32) 512         activation_65[0][0]
# __________________________________________________________________________________________________
# add_28 (Add)                    (None, 112, 112, 32) 0           conv_expand_0_2_2[0][0]
#                                                                  conv_expand_0_2_3[0][0]
# __________________________________________________________________________________________________
# BN_0_2 (BatchNormalization)     (None, 112, 112, 32) 128         add_28[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 112, 112, 32) 0           BN_0_2[0][0]
# __________________________________________________________________________________________________
# conv_expand_0_3_1 (Conv2D)      (None, 56, 56, 64)   18432       activation_67[0][0]
# __________________________________________________________________________________________________
# BN_expand0_3 (BatchNormalizatio (None, 56, 56, 64)   256         conv_expand_0_3_1[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 56, 56, 64)   0           BN_expand0_3[0][0]
# __________________________________________________________________________________________________
# conv_expand_0_3_2 (Conv2D)      (None, 56, 56, 64)   36864       activation_68[0][0]
# __________________________________________________________________________________________________
# conv_expand_0_3_3 (Conv2D)      (None, 56, 56, 64)   2048        activation_67[0][0]
# __________________________________________________________________________________________________
# add_29 (Add)                    (None, 56, 56, 64)   0           conv_expand_0_3_2[0][0]
#                                                                  conv_expand_0_3_3[0][0]
# __________________________________________________________________________________________________
# BN_0_3 (BatchNormalization)     (None, 56, 56, 64)   256         add_29[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 56, 56, 64)   0           BN_0_3[0][0]
# __________________________________________________________________________________________________
# conv_init_1 (Conv2D)            (None, 56, 56, 100)  57600       activation_69[0][0]
# __________________________________________________________________________________________________
# conv_init_2 (Conv2D)            (None, 56, 56, 100)  57600       activation_69[0][0]
# __________________________________________________________________________________________________
# conv_init_3 (Conv2D)            (None, 56, 56, 100)  57600       activation_69[0][0]
# __________________________________________________________________________________________________
# conv_init_4 (Conv2D)            (None, 56, 56, 100)  57600       activation_69[0][0]
# __________________________________________________________________________________________________
# conv_init_5 (Conv2D)            (None, 56, 56, 100)  57600       activation_69[0][0]
# __________________________________________________________________________________________________
# conv_init_6 (Conv2D)            (None, 56, 56, 100)  57600       activation_69[0][0]
# __________________________________________________________________________________________________
# conv_init_7 (Conv2D)            (None, 56, 56, 100)  57600       activation_69[0][0]
# __________________________________________________________________________________________________
# conv_init_8 (Conv2D)            (None, 56, 56, 100)  57600       activation_69[0][0]
# __________________________________________________________________________________________________
# BN_init_1 (BatchNormalization)  (None, 56, 56, 100)  400         conv_init_1[0][0]
# __________________________________________________________________________________________________
# BN_init_2 (BatchNormalization)  (None, 56, 56, 100)  400         conv_init_2[0][0]
# __________________________________________________________________________________________________
# BN_init_3 (BatchNormalization)  (None, 56, 56, 100)  400         conv_init_3[0][0]
# __________________________________________________________________________________________________
# BN_init_4 (BatchNormalization)  (None, 56, 56, 100)  400         conv_init_4[0][0]
# __________________________________________________________________________________________________
# BN_init_5 (BatchNormalization)  (None, 56, 56, 100)  400         conv_init_5[0][0]
# __________________________________________________________________________________________________
# BN_init_6 (BatchNormalization)  (None, 56, 56, 100)  400         conv_init_6[0][0]
# __________________________________________________________________________________________________
# BN_init_7 (BatchNormalization)  (None, 56, 56, 100)  400         conv_init_7[0][0]
# __________________________________________________________________________________________________
# BN_init_8 (BatchNormalization)  (None, 56, 56, 100)  400         conv_init_8[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 56, 56, 100)  0           BN_init_1[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, 56, 56, 100)  0           BN_init_2[0][0]
# __________________________________________________________________________________________________
# activation_84 (Activation)      (None, 56, 56, 100)  0           BN_init_3[0][0]
# __________________________________________________________________________________________________
# activation_91 (Activation)      (None, 56, 56, 100)  0           BN_init_4[0][0]
# __________________________________________________________________________________________________
# activation_98 (Activation)      (None, 56, 56, 100)  0           BN_init_5[0][0]
# __________________________________________________________________________________________________
# activation_105 (Activation)     (None, 56, 56, 100)  0           BN_init_6[0][0]
# __________________________________________________________________________________________________
# activation_112 (Activation)     (None, 56, 56, 100)  0           BN_init_7[0][0]
# __________________________________________________________________________________________________
# activation_119 (Activation)     (None, 56, 56, 100)  0           BN_init_8[0][0]
# __________________________________________________________________________________________________
# conv_expand_1_1_1 (Conv2D)      (None, 56, 56, 16)   14400       activation_70[0][0]
# __________________________________________________________________________________________________
# conv_expand_2_1_1 (Conv2D)      (None, 56, 56, 16)   14400       activation_77[0][0]
# __________________________________________________________________________________________________
# conv_expand_3_1_1 (Conv2D)      (None, 56, 56, 16)   14400       activation_84[0][0]
# __________________________________________________________________________________________________
# conv_expand_4_1_1 (Conv2D)      (None, 56, 56, 16)   14400       activation_91[0][0]
# __________________________________________________________________________________________________
# conv_expand_5_1_1 (Conv2D)      (None, 56, 56, 16)   14400       activation_98[0][0]
# __________________________________________________________________________________________________
# conv_expand_6_1_1 (Conv2D)      (None, 56, 56, 16)   14400       activation_105[0][0]
# __________________________________________________________________________________________________
# conv_expand_7_1_1 (Conv2D)      (None, 56, 56, 16)   14400       activation_112[0][0]
# __________________________________________________________________________________________________
# conv_expand_8_1_1 (Conv2D)      (None, 56, 56, 16)   14400       activation_119[0][0]
# __________________________________________________________________________________________________
# BN_expand1_1 (BatchNormalizatio (None, 56, 56, 16)   64          conv_expand_1_1_1[0][0]
# __________________________________________________________________________________________________
# BN_expand2_1 (BatchNormalizatio (None, 56, 56, 16)   64          conv_expand_2_1_1[0][0]
# __________________________________________________________________________________________________
# BN_expand3_1 (BatchNormalizatio (None, 56, 56, 16)   64          conv_expand_3_1_1[0][0]
# __________________________________________________________________________________________________
# BN_expand4_1 (BatchNormalizatio (None, 56, 56, 16)   64          conv_expand_4_1_1[0][0]
# __________________________________________________________________________________________________
# BN_expand5_1 (BatchNormalizatio (None, 56, 56, 16)   64          conv_expand_5_1_1[0][0]
# __________________________________________________________________________________________________
# BN_expand6_1 (BatchNormalizatio (None, 56, 56, 16)   64          conv_expand_6_1_1[0][0]
# __________________________________________________________________________________________________
# BN_expand7_1 (BatchNormalizatio (None, 56, 56, 16)   64          conv_expand_7_1_1[0][0]
# __________________________________________________________________________________________________
# BN_expand8_1 (BatchNormalizatio (None, 56, 56, 16)   64          conv_expand_8_1_1[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, 56, 56, 16)   0           BN_expand1_1[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, 56, 56, 16)   0           BN_expand2_1[0][0]
# __________________________________________________________________________________________________
# activation_85 (Activation)      (None, 56, 56, 16)   0           BN_expand3_1[0][0]
# __________________________________________________________________________________________________
# activation_92 (Activation)      (None, 56, 56, 16)   0           BN_expand4_1[0][0]
# __________________________________________________________________________________________________
# activation_99 (Activation)      (None, 56, 56, 16)   0           BN_expand5_1[0][0]
# __________________________________________________________________________________________________
# activation_106 (Activation)     (None, 56, 56, 16)   0           BN_expand6_1[0][0]
# __________________________________________________________________________________________________
# activation_113 (Activation)     (None, 56, 56, 16)   0           BN_expand7_1[0][0]
# __________________________________________________________________________________________________
# activation_120 (Activation)     (None, 56, 56, 16)   0           BN_expand8_1[0][0]
# __________________________________________________________________________________________________
# conv_expand_1_1_2 (Conv2D)      (None, 56, 56, 16)   2304        activation_71[0][0]
# __________________________________________________________________________________________________
# conv_expand_1_1_3 (Conv2D)      (None, 56, 56, 16)   1600        activation_70[0][0]
# __________________________________________________________________________________________________
# conv_expand_2_1_2 (Conv2D)      (None, 56, 56, 16)   2304        activation_78[0][0]
# __________________________________________________________________________________________________
# conv_expand_2_1_3 (Conv2D)      (None, 56, 56, 16)   1600        activation_77[0][0]
# __________________________________________________________________________________________________
# conv_expand_3_1_2 (Conv2D)      (None, 56, 56, 16)   2304        activation_85[0][0]
# __________________________________________________________________________________________________
# conv_expand_3_1_3 (Conv2D)      (None, 56, 56, 16)   1600        activation_84[0][0]
# __________________________________________________________________________________________________
# conv_expand_4_1_2 (Conv2D)      (None, 56, 56, 16)   2304        activation_92[0][0]
# __________________________________________________________________________________________________
# conv_expand_4_1_3 (Conv2D)      (None, 56, 56, 16)   1600        activation_91[0][0]
# __________________________________________________________________________________________________
# conv_expand_5_1_2 (Conv2D)      (None, 56, 56, 16)   2304        activation_99[0][0]
# __________________________________________________________________________________________________
# conv_expand_5_1_3 (Conv2D)      (None, 56, 56, 16)   1600        activation_98[0][0]
# __________________________________________________________________________________________________
# conv_expand_6_1_2 (Conv2D)      (None, 56, 56, 16)   2304        activation_106[0][0]
# __________________________________________________________________________________________________
# conv_expand_6_1_3 (Conv2D)      (None, 56, 56, 16)   1600        activation_105[0][0]
# __________________________________________________________________________________________________
# conv_expand_7_1_2 (Conv2D)      (None, 56, 56, 16)   2304        activation_113[0][0]
# __________________________________________________________________________________________________
# conv_expand_7_1_3 (Conv2D)      (None, 56, 56, 16)   1600        activation_112[0][0]
# __________________________________________________________________________________________________
# conv_expand_8_1_2 (Conv2D)      (None, 56, 56, 16)   2304        activation_120[0][0]
# __________________________________________________________________________________________________
# conv_expand_8_1_3 (Conv2D)      (None, 56, 56, 16)   1600        activation_119[0][0]
# __________________________________________________________________________________________________
# add_30 (Add)                    (None, 56, 56, 16)   0           conv_expand_1_1_2[0][0]
#                                                                  conv_expand_1_1_3[0][0]
# __________________________________________________________________________________________________
# add_33 (Add)                    (None, 56, 56, 16)   0           conv_expand_2_1_2[0][0]
#                                                                  conv_expand_2_1_3[0][0]
# __________________________________________________________________________________________________
# add_36 (Add)                    (None, 56, 56, 16)   0           conv_expand_3_1_2[0][0]
#                                                                  conv_expand_3_1_3[0][0]
# __________________________________________________________________________________________________
# add_39 (Add)                    (None, 56, 56, 16)   0           conv_expand_4_1_2[0][0]
#                                                                  conv_expand_4_1_3[0][0]
# __________________________________________________________________________________________________
# add_42 (Add)                    (None, 56, 56, 16)   0           conv_expand_5_1_2[0][0]
#                                                                  conv_expand_5_1_3[0][0]
# __________________________________________________________________________________________________
# add_45 (Add)                    (None, 56, 56, 16)   0           conv_expand_6_1_2[0][0]
#                                                                  conv_expand_6_1_3[0][0]
# __________________________________________________________________________________________________
# add_48 (Add)                    (None, 56, 56, 16)   0           conv_expand_7_1_2[0][0]
#                                                                  conv_expand_7_1_3[0][0]
# __________________________________________________________________________________________________
# add_51 (Add)                    (None, 56, 56, 16)   0           conv_expand_8_1_2[0][0]
#                                                                  conv_expand_8_1_3[0][0]
# __________________________________________________________________________________________________
# BN_1_1 (BatchNormalization)     (None, 56, 56, 16)   64          add_30[0][0]
# __________________________________________________________________________________________________
# BN_2_1 (BatchNormalization)     (None, 56, 56, 16)   64          add_33[0][0]
# __________________________________________________________________________________________________
# BN_3_1 (BatchNormalization)     (None, 56, 56, 16)   64          add_36[0][0]
# __________________________________________________________________________________________________
# BN_4_1 (BatchNormalization)     (None, 56, 56, 16)   64          add_39[0][0]
# __________________________________________________________________________________________________
# BN_5_1 (BatchNormalization)     (None, 56, 56, 16)   64          add_42[0][0]
# __________________________________________________________________________________________________
# BN_6_1 (BatchNormalization)     (None, 56, 56, 16)   64          add_45[0][0]
# __________________________________________________________________________________________________
# BN_7_1 (BatchNormalization)     (None, 56, 56, 16)   64          add_48[0][0]
# __________________________________________________________________________________________________
# BN_8_1 (BatchNormalization)     (None, 56, 56, 16)   64          add_51[0][0]
# __________________________________________________________________________________________________
# activation_72 (Activation)      (None, 56, 56, 16)   0           BN_1_1[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, 56, 56, 16)   0           BN_2_1[0][0]
# __________________________________________________________________________________________________
# activation_86 (Activation)      (None, 56, 56, 16)   0           BN_3_1[0][0]
# __________________________________________________________________________________________________
# activation_93 (Activation)      (None, 56, 56, 16)   0           BN_4_1[0][0]
# __________________________________________________________________________________________________
# activation_100 (Activation)     (None, 56, 56, 16)   0           BN_5_1[0][0]
# __________________________________________________________________________________________________
# activation_107 (Activation)     (None, 56, 56, 16)   0           BN_6_1[0][0]
# __________________________________________________________________________________________________
# activation_114 (Activation)     (None, 56, 56, 16)   0           BN_7_1[0][0]
# __________________________________________________________________________________________________
# activation_121 (Activation)     (None, 56, 56, 16)   0           BN_8_1[0][0]
# __________________________________________________________________________________________________
# conv_expand_1_2_1 (Conv2D)      (None, 28, 28, 32)   4608        activation_72[0][0]
# __________________________________________________________________________________________________
# conv_expand_2_2_1 (Conv2D)      (None, 28, 28, 32)   4608        activation_79[0][0]
# __________________________________________________________________________________________________
# conv_expand_3_2_1 (Conv2D)      (None, 28, 28, 32)   4608        activation_86[0][0]
# __________________________________________________________________________________________________
# conv_expand_4_2_1 (Conv2D)      (None, 28, 28, 32)   4608        activation_93[0][0]
# __________________________________________________________________________________________________
# conv_expand_5_2_1 (Conv2D)      (None, 28, 28, 32)   4608        activation_100[0][0]
# __________________________________________________________________________________________________
# conv_expand_6_2_1 (Conv2D)      (None, 28, 28, 32)   4608        activation_107[0][0]
# __________________________________________________________________________________________________
# conv_expand_7_2_1 (Conv2D)      (None, 28, 28, 32)   4608        activation_114[0][0]
# __________________________________________________________________________________________________
# conv_expand_8_2_1 (Conv2D)      (None, 28, 28, 32)   4608        activation_121[0][0]
# __________________________________________________________________________________________________
# BN_expand1_2 (BatchNormalizatio (None, 28, 28, 32)   128         conv_expand_1_2_1[0][0]
# __________________________________________________________________________________________________
# BN_expand2_2 (BatchNormalizatio (None, 28, 28, 32)   128         conv_expand_2_2_1[0][0]
# __________________________________________________________________________________________________
# BN_expand3_2 (BatchNormalizatio (None, 28, 28, 32)   128         conv_expand_3_2_1[0][0]
# __________________________________________________________________________________________________
# BN_expand4_2 (BatchNormalizatio (None, 28, 28, 32)   128         conv_expand_4_2_1[0][0]
# __________________________________________________________________________________________________
# BN_expand5_2 (BatchNormalizatio (None, 28, 28, 32)   128         conv_expand_5_2_1[0][0]
# __________________________________________________________________________________________________
# BN_expand6_2 (BatchNormalizatio (None, 28, 28, 32)   128         conv_expand_6_2_1[0][0]
# __________________________________________________________________________________________________
# BN_expand7_2 (BatchNormalizatio (None, 28, 28, 32)   128         conv_expand_7_2_1[0][0]
# __________________________________________________________________________________________________
# BN_expand8_2 (BatchNormalizatio (None, 28, 28, 32)   128         conv_expand_8_2_1[0][0]
# __________________________________________________________________________________________________
# activation_73 (Activation)      (None, 28, 28, 32)   0           BN_expand1_2[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, 28, 28, 32)   0           BN_expand2_2[0][0]
# __________________________________________________________________________________________________
# activation_87 (Activation)      (None, 28, 28, 32)   0           BN_expand3_2[0][0]
# __________________________________________________________________________________________________
# activation_94 (Activation)      (None, 28, 28, 32)   0           BN_expand4_2[0][0]
# __________________________________________________________________________________________________
# activation_101 (Activation)     (None, 28, 28, 32)   0           BN_expand5_2[0][0]
# __________________________________________________________________________________________________
# activation_108 (Activation)     (None, 28, 28, 32)   0           BN_expand6_2[0][0]
# __________________________________________________________________________________________________
# activation_115 (Activation)     (None, 28, 28, 32)   0           BN_expand7_2[0][0]
# __________________________________________________________________________________________________
# activation_122 (Activation)     (None, 28, 28, 32)   0           BN_expand8_2[0][0]
# __________________________________________________________________________________________________
# conv_expand_1_2_2 (Conv2D)      (None, 28, 28, 32)   9216        activation_73[0][0]
# __________________________________________________________________________________________________
# conv_expand_1_2_3 (Conv2D)      (None, 28, 28, 32)   512         activation_72[0][0]
# __________________________________________________________________________________________________
# conv_expand_2_2_2 (Conv2D)      (None, 28, 28, 32)   9216        activation_80[0][0]
# __________________________________________________________________________________________________
# conv_expand_2_2_3 (Conv2D)      (None, 28, 28, 32)   512         activation_79[0][0]
# __________________________________________________________________________________________________
# conv_expand_3_2_2 (Conv2D)      (None, 28, 28, 32)   9216        activation_87[0][0]
# __________________________________________________________________________________________________
# conv_expand_3_2_3 (Conv2D)      (None, 28, 28, 32)   512         activation_86[0][0]
# __________________________________________________________________________________________________
# conv_expand_4_2_2 (Conv2D)      (None, 28, 28, 32)   9216        activation_94[0][0]
# __________________________________________________________________________________________________
# conv_expand_4_2_3 (Conv2D)      (None, 28, 28, 32)   512         activation_93[0][0]
# __________________________________________________________________________________________________
# conv_expand_5_2_2 (Conv2D)      (None, 28, 28, 32)   9216        activation_101[0][0]
# __________________________________________________________________________________________________
# conv_expand_5_2_3 (Conv2D)      (None, 28, 28, 32)   512         activation_100[0][0]
# __________________________________________________________________________________________________
# conv_expand_6_2_2 (Conv2D)      (None, 28, 28, 32)   9216        activation_108[0][0]
# __________________________________________________________________________________________________
# conv_expand_6_2_3 (Conv2D)      (None, 28, 28, 32)   512         activation_107[0][0]
# __________________________________________________________________________________________________
# conv_expand_7_2_2 (Conv2D)      (None, 28, 28, 32)   9216        activation_115[0][0]
# __________________________________________________________________________________________________
# conv_expand_7_2_3 (Conv2D)      (None, 28, 28, 32)   512         activation_114[0][0]
# __________________________________________________________________________________________________
# conv_expand_8_2_2 (Conv2D)      (None, 28, 28, 32)   9216        activation_122[0][0]
# __________________________________________________________________________________________________
# conv_expand_8_2_3 (Conv2D)      (None, 28, 28, 32)   512         activation_121[0][0]
# __________________________________________________________________________________________________
# add_31 (Add)                    (None, 28, 28, 32)   0           conv_expand_1_2_2[0][0]
#                                                                  conv_expand_1_2_3[0][0]
# __________________________________________________________________________________________________
# add_34 (Add)                    (None, 28, 28, 32)   0           conv_expand_2_2_2[0][0]
#                                                                  conv_expand_2_2_3[0][0]
# __________________________________________________________________________________________________
# add_37 (Add)                    (None, 28, 28, 32)   0           conv_expand_3_2_2[0][0]
#                                                                  conv_expand_3_2_3[0][0]
# __________________________________________________________________________________________________
# add_40 (Add)                    (None, 28, 28, 32)   0           conv_expand_4_2_2[0][0]
#                                                                  conv_expand_4_2_3[0][0]
# __________________________________________________________________________________________________
# add_43 (Add)                    (None, 28, 28, 32)   0           conv_expand_5_2_2[0][0]
#                                                                  conv_expand_5_2_3[0][0]
# __________________________________________________________________________________________________
# add_46 (Add)                    (None, 28, 28, 32)   0           conv_expand_6_2_2[0][0]
#                                                                  conv_expand_6_2_3[0][0]
# __________________________________________________________________________________________________
# add_49 (Add)                    (None, 28, 28, 32)   0           conv_expand_7_2_2[0][0]
#                                                                  conv_expand_7_2_3[0][0]
# __________________________________________________________________________________________________
# add_52 (Add)                    (None, 28, 28, 32)   0           conv_expand_8_2_2[0][0]
#                                                                  conv_expand_8_2_3[0][0]
# __________________________________________________________________________________________________
# BN_1_2 (BatchNormalization)     (None, 28, 28, 32)   128         add_31[0][0]
# __________________________________________________________________________________________________
# BN_2_2 (BatchNormalization)     (None, 28, 28, 32)   128         add_34[0][0]
# __________________________________________________________________________________________________
# BN_3_2 (BatchNormalization)     (None, 28, 28, 32)   128         add_37[0][0]
# __________________________________________________________________________________________________
# BN_4_2 (BatchNormalization)     (None, 28, 28, 32)   128         add_40[0][0]
# __________________________________________________________________________________________________
# BN_5_2 (BatchNormalization)     (None, 28, 28, 32)   128         add_43[0][0]
# __________________________________________________________________________________________________
# BN_6_2 (BatchNormalization)     (None, 28, 28, 32)   128         add_46[0][0]
# __________________________________________________________________________________________________
# BN_7_2 (BatchNormalization)     (None, 28, 28, 32)   128         add_49[0][0]
# __________________________________________________________________________________________________
# BN_8_2 (BatchNormalization)     (None, 28, 28, 32)   128         add_52[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, 28, 28, 32)   0           BN_1_2[0][0]
# __________________________________________________________________________________________________
# activation_81 (Activation)      (None, 28, 28, 32)   0           BN_2_2[0][0]
# __________________________________________________________________________________________________
# activation_88 (Activation)      (None, 28, 28, 32)   0           BN_3_2[0][0]
# __________________________________________________________________________________________________
# activation_95 (Activation)      (None, 28, 28, 32)   0           BN_4_2[0][0]
# __________________________________________________________________________________________________
# activation_102 (Activation)     (None, 28, 28, 32)   0           BN_5_2[0][0]
# __________________________________________________________________________________________________
# activation_109 (Activation)     (None, 28, 28, 32)   0           BN_6_2[0][0]
# __________________________________________________________________________________________________
# activation_116 (Activation)     (None, 28, 28, 32)   0           BN_7_2[0][0]
# __________________________________________________________________________________________________
# activation_123 (Activation)     (None, 28, 28, 32)   0           BN_8_2[0][0]
# __________________________________________________________________________________________________
# conv_expand_1_3_1 (Conv2D)      (None, 14, 14, 64)   18432       activation_74[0][0]
# __________________________________________________________________________________________________
# conv_expand_2_3_1 (Conv2D)      (None, 14, 14, 64)   18432       activation_81[0][0]
# __________________________________________________________________________________________________
# conv_expand_3_3_1 (Conv2D)      (None, 14, 14, 64)   18432       activation_88[0][0]
# __________________________________________________________________________________________________
# conv_expand_4_3_1 (Conv2D)      (None, 14, 14, 64)   18432       activation_95[0][0]
# __________________________________________________________________________________________________
# conv_expand_5_3_1 (Conv2D)      (None, 14, 14, 64)   18432       activation_102[0][0]
# __________________________________________________________________________________________________
# conv_expand_6_3_1 (Conv2D)      (None, 14, 14, 64)   18432       activation_109[0][0]
# __________________________________________________________________________________________________
# conv_expand_7_3_1 (Conv2D)      (None, 14, 14, 64)   18432       activation_116[0][0]
# __________________________________________________________________________________________________
# conv_expand_8_3_1 (Conv2D)      (None, 14, 14, 64)   18432       activation_123[0][0]
# __________________________________________________________________________________________________
# BN_expand1_3 (BatchNormalizatio (None, 14, 14, 64)   256         conv_expand_1_3_1[0][0]
# __________________________________________________________________________________________________
# BN_expand2_3 (BatchNormalizatio (None, 14, 14, 64)   256         conv_expand_2_3_1[0][0]
# __________________________________________________________________________________________________
# BN_expand3_3 (BatchNormalizatio (None, 14, 14, 64)   256         conv_expand_3_3_1[0][0]
# __________________________________________________________________________________________________
# BN_expand4_3 (BatchNormalizatio (None, 14, 14, 64)   256         conv_expand_4_3_1[0][0]
# __________________________________________________________________________________________________
# BN_expand5_3 (BatchNormalizatio (None, 14, 14, 64)   256         conv_expand_5_3_1[0][0]
# __________________________________________________________________________________________________
# BN_expand6_3 (BatchNormalizatio (None, 14, 14, 64)   256         conv_expand_6_3_1[0][0]
# __________________________________________________________________________________________________
# BN_expand7_3 (BatchNormalizatio (None, 14, 14, 64)   256         conv_expand_7_3_1[0][0]
# __________________________________________________________________________________________________
# BN_expand8_3 (BatchNormalizatio (None, 14, 14, 64)   256         conv_expand_8_3_1[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, 14, 14, 64)   0           BN_expand1_3[0][0]
# __________________________________________________________________________________________________
# activation_82 (Activation)      (None, 14, 14, 64)   0           BN_expand2_3[0][0]
# __________________________________________________________________________________________________
# activation_89 (Activation)      (None, 14, 14, 64)   0           BN_expand3_3[0][0]
# __________________________________________________________________________________________________
# activation_96 (Activation)      (None, 14, 14, 64)   0           BN_expand4_3[0][0]
# __________________________________________________________________________________________________
# activation_103 (Activation)     (None, 14, 14, 64)   0           BN_expand5_3[0][0]
# __________________________________________________________________________________________________
# activation_110 (Activation)     (None, 14, 14, 64)   0           BN_expand6_3[0][0]
# __________________________________________________________________________________________________
# activation_117 (Activation)     (None, 14, 14, 64)   0           BN_expand7_3[0][0]
# __________________________________________________________________________________________________
# activation_124 (Activation)     (None, 14, 14, 64)   0           BN_expand8_3[0][0]
# __________________________________________________________________________________________________
# conv_expand_1_3_2 (Conv2D)      (None, 14, 14, 64)   36864       activation_75[0][0]
# __________________________________________________________________________________________________
# conv_expand_1_3_3 (Conv2D)      (None, 14, 14, 64)   2048        activation_74[0][0]
# __________________________________________________________________________________________________
# conv_expand_2_3_2 (Conv2D)      (None, 14, 14, 64)   36864       activation_82[0][0]
# __________________________________________________________________________________________________
# conv_expand_2_3_3 (Conv2D)      (None, 14, 14, 64)   2048        activation_81[0][0]
# __________________________________________________________________________________________________
# conv_expand_3_3_2 (Conv2D)      (None, 14, 14, 64)   36864       activation_89[0][0]
# __________________________________________________________________________________________________
# conv_expand_3_3_3 (Conv2D)      (None, 14, 14, 64)   2048        activation_88[0][0]
# __________________________________________________________________________________________________
# conv_expand_4_3_2 (Conv2D)      (None, 14, 14, 64)   36864       activation_96[0][0]
# __________________________________________________________________________________________________
# conv_expand_4_3_3 (Conv2D)      (None, 14, 14, 64)   2048        activation_95[0][0]
# __________________________________________________________________________________________________
# conv_expand_5_3_2 (Conv2D)      (None, 14, 14, 64)   36864       activation_103[0][0]
# __________________________________________________________________________________________________
# conv_expand_5_3_3 (Conv2D)      (None, 14, 14, 64)   2048        activation_102[0][0]
# __________________________________________________________________________________________________
# conv_expand_6_3_2 (Conv2D)      (None, 14, 14, 64)   36864       activation_110[0][0]
# __________________________________________________________________________________________________
# conv_expand_6_3_3 (Conv2D)      (None, 14, 14, 64)   2048        activation_109[0][0]
# __________________________________________________________________________________________________
# conv_expand_7_3_2 (Conv2D)      (None, 14, 14, 64)   36864       activation_117[0][0]
# __________________________________________________________________________________________________
# conv_expand_7_3_3 (Conv2D)      (None, 14, 14, 64)   2048        activation_116[0][0]
# __________________________________________________________________________________________________
# conv_expand_8_3_2 (Conv2D)      (None, 14, 14, 64)   36864       activation_124[0][0]
# __________________________________________________________________________________________________
# conv_expand_8_3_3 (Conv2D)      (None, 14, 14, 64)   2048        activation_123[0][0]
# __________________________________________________________________________________________________
# add_32 (Add)                    (None, 14, 14, 64)   0           conv_expand_1_3_2[0][0]
#                                                                  conv_expand_1_3_3[0][0]
# __________________________________________________________________________________________________
# add_35 (Add)                    (None, 14, 14, 64)   0           conv_expand_2_3_2[0][0]
#                                                                  conv_expand_2_3_3[0][0]
# __________________________________________________________________________________________________
# add_38 (Add)                    (None, 14, 14, 64)   0           conv_expand_3_3_2[0][0]
#                                                                  conv_expand_3_3_3[0][0]
# __________________________________________________________________________________________________
# add_41 (Add)                    (None, 14, 14, 64)   0           conv_expand_4_3_2[0][0]
#                                                                  conv_expand_4_3_3[0][0]
# __________________________________________________________________________________________________
# add_44 (Add)                    (None, 14, 14, 64)   0           conv_expand_5_3_2[0][0]
#                                                                  conv_expand_5_3_3[0][0]
# __________________________________________________________________________________________________
# add_47 (Add)                    (None, 14, 14, 64)   0           conv_expand_6_3_2[0][0]
#                                                                  conv_expand_6_3_3[0][0]
# __________________________________________________________________________________________________
# add_50 (Add)                    (None, 14, 14, 64)   0           conv_expand_7_3_2[0][0]
#                                                                  conv_expand_7_3_3[0][0]
# __________________________________________________________________________________________________
# add_53 (Add)                    (None, 14, 14, 64)   0           conv_expand_8_3_2[0][0]
#                                                                  conv_expand_8_3_3[0][0]
# __________________________________________________________________________________________________
# BN_1_3 (BatchNormalization)     (None, 14, 14, 64)   256         add_32[0][0]
# __________________________________________________________________________________________________
# BN_2_3 (BatchNormalization)     (None, 14, 14, 64)   256         add_35[0][0]
# __________________________________________________________________________________________________
# BN_3_3 (BatchNormalization)     (None, 14, 14, 64)   256         add_38[0][0]
# __________________________________________________________________________________________________
# BN_4_3 (BatchNormalization)     (None, 14, 14, 64)   256         add_41[0][0]
# __________________________________________________________________________________________________
# BN_5_3 (BatchNormalization)     (None, 14, 14, 64)   256         add_44[0][0]
# __________________________________________________________________________________________________
# BN_6_3 (BatchNormalization)     (None, 14, 14, 64)   256         add_47[0][0]
# __________________________________________________________________________________________________
# BN_7_3 (BatchNormalization)     (None, 14, 14, 64)   256         add_50[0][0]
# __________________________________________________________________________________________________
# BN_8_3 (BatchNormalization)     (None, 14, 14, 64)   256         add_53[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, 14, 14, 64)   0           BN_1_3[0][0]
# __________________________________________________________________________________________________
# activation_83 (Activation)      (None, 14, 14, 64)   0           BN_2_3[0][0]
# __________________________________________________________________________________________________
# activation_90 (Activation)      (None, 14, 14, 64)   0           BN_3_3[0][0]
# __________________________________________________________________________________________________
# activation_97 (Activation)      (None, 14, 14, 64)   0           BN_4_3[0][0]
# __________________________________________________________________________________________________
# activation_104 (Activation)     (None, 14, 14, 64)   0           BN_5_3[0][0]
# __________________________________________________________________________________________________
# activation_111 (Activation)     (None, 14, 14, 64)   0           BN_6_3[0][0]
# __________________________________________________________________________________________________
# activation_118 (Activation)     (None, 14, 14, 64)   0           BN_7_3[0][0]
# __________________________________________________________________________________________________
# activation_125 (Activation)     (None, 14, 14, 64)   0           BN_8_3[0][0]
# __________________________________________________________________________________________________
# flatten_8 (Flatten)             (None, 12544)        0           activation_76[0][0]
# __________________________________________________________________________________________________
# flatten_9 (Flatten)             (None, 12544)        0           activation_83[0][0]
# __________________________________________________________________________________________________
# flatten_10 (Flatten)            (None, 12544)        0           activation_90[0][0]
# __________________________________________________________________________________________________
# flatten_11 (Flatten)            (None, 12544)        0           activation_97[0][0]
# __________________________________________________________________________________________________
# flatten_12 (Flatten)            (None, 12544)        0           activation_104[0][0]
# __________________________________________________________________________________________________
# flatten_13 (Flatten)            (None, 12544)        0           activation_111[0][0]
# __________________________________________________________________________________________________
# flatten_14 (Flatten)            (None, 12544)        0           activation_118[0][0]
# __________________________________________________________________________________________________
# flatten_15 (Flatten)            (None, 12544)        0           activation_125[0][0]
# __________________________________________________________________________________________________
# dense_24 (Dense)                (None, 64)           802880      flatten_8[0][0]
# __________________________________________________________________________________________________
# dense_27 (Dense)                (None, 64)           802880      flatten_9[0][0]
# __________________________________________________________________________________________________
# dense_30 (Dense)                (None, 64)           802880      flatten_10[0][0]
# __________________________________________________________________________________________________
# dense_33 (Dense)                (None, 64)           802880      flatten_11[0][0]
# __________________________________________________________________________________________________
# dense_36 (Dense)                (None, 64)           802880      flatten_12[0][0]
# __________________________________________________________________________________________________
# dense_39 (Dense)                (None, 64)           802880      flatten_13[0][0]
# __________________________________________________________________________________________________
# dense_42 (Dense)                (None, 64)           802880      flatten_14[0][0]
# __________________________________________________________________________________________________
# dense_45 (Dense)                (None, 64)           802880      flatten_15[0][0]
# __________________________________________________________________________________________________
# dense_25 (Dense)                (None, 32)           2080        dense_24[0][0]
# __________________________________________________________________________________________________
# dense_28 (Dense)                (None, 32)           2080        dense_27[0][0]
# __________________________________________________________________________________________________
# dense_31 (Dense)                (None, 32)           2080        dense_30[0][0]
# __________________________________________________________________________________________________
# dense_34 (Dense)                (None, 32)           2080        dense_33[0][0]
# __________________________________________________________________________________________________
# dense_37 (Dense)                (None, 32)           2080        dense_36[0][0]
# __________________________________________________________________________________________________
# dense_40 (Dense)                (None, 32)           2080        dense_39[0][0]
# __________________________________________________________________________________________________
# dense_43 (Dense)                (None, 32)           2080        dense_42[0][0]
# __________________________________________________________________________________________________
# dense_46 (Dense)                (None, 32)           2080        dense_45[0][0]
# __________________________________________________________________________________________________
# dense_26 (Dense)                (None, 16)           528         dense_25[0][0]
# __________________________________________________________________________________________________
# dense_29 (Dense)                (None, 16)           528         dense_28[0][0]
# __________________________________________________________________________________________________
# dense_32 (Dense)                (None, 16)           528         dense_31[0][0]
# __________________________________________________________________________________________________
# dense_35 (Dense)                (None, 16)           528         dense_34[0][0]
# __________________________________________________________________________________________________
# dense_38 (Dense)                (None, 16)           528         dense_37[0][0]
# __________________________________________________________________________________________________
# dense_41 (Dense)                (None, 16)           528         dense_40[0][0]
# __________________________________________________________________________________________________
# dense_44 (Dense)                (None, 16)           528         dense_43[0][0]
# __________________________________________________________________________________________________
# dense_47 (Dense)                (None, 16)           528         dense_46[0][0]
# __________________________________________________________________________________________________
# age_output (Dense)              (None, 5)            85          dense_26[0][0]
# __________________________________________________________________________________________________
# bag_output (Dense)              (None, 3)            51          dense_29[0][0]
# __________________________________________________________________________________________________
# bodypose_output (Dense)         (None, 3)            51          dense_32[0][0]
# __________________________________________________________________________________________________
# emotion_output (Dense)          (None, 4)            68          dense_35[0][0]
# __________________________________________________________________________________________________
# footwear_output (Dense)         (None, 3)            51          dense_38[0][0]
# __________________________________________________________________________________________________
# gender_output (Dense)           (None, 2)            34          dense_41[0][0]
# __________________________________________________________________________________________________
# imagequality_output (Dense)     (None, 3)            51          dense_44[0][0]
# __________________________________________________________________________________________________
# weight_output (Dense)           (None, 4)            68          dense_47[0][0]
# ==================================================================================================
# Total params: 7,729,383
# Trainable params: 7,723,551
# Non-trainable params: 5,832
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.callbacks import *

class CyclicLR(Callback):
    """This callback implements a cyclical learning rate policy (CLR).
    The method cycles the learning rate between two boundaries with
    some constant frequency, as detailed in this paper (https://arxiv.org/abs/1506.01186).
    The amplitude of the cycle can be scaled on a per-iteration or 
    per-cycle basis.
    This class has three built-in policies, as put forth in the paper.
    "triangular":
        A basic triangular cycle w/ no amplitude scaling.
    "triangular2":
        A basic triangular cycle that scales initial amplitude by half each cycle.
    "exp_range":
        A cycle that scales initial amplitude by gamma**(cycle iterations) at each 
        cycle iteration.
    For more detail, please see paper.
    
    # Example
        ```python
            clr = CyclicLR(base_lr=0.001, max_lr=0.006,
                                step_size=2000., mode='triangular')
            model.fit(X_train, Y_train, callbacks=[clr])
        ```
    
    Class also supports custom scaling functions:
        ```python
            clr_fn = lambda x: 0.5*(1+np.sin(x*np.pi/2.))
            clr = CyclicLR(base_lr=0.001, max_lr=0.006,
                                step_size=2000., scale_fn=clr_fn,
                                scale_mode='cycle')
            model.fit(X_train, Y_train, callbacks=[clr])
        ```    
    # Arguments
        base_lr: initial learning rate which is the
            lower boundary in the cycle.
        max_lr: upper boundary in the cycle. Functionally,
            it defines the cycle amplitude (max_lr - base_lr).
            The lr at any cycle is the sum of base_lr
            and some scaling of the amplitude; therefore 
            max_lr may not actually be reached depending on
            scaling function.
        step_size: number of training iterations per
            half cycle. Authors suggest setting step_size
            2-8 x training iterations in epoch.
        mode: one of {triangular, triangular2, exp_range}.
            Default 'triangular'.
            Values correspond to policies detailed above.
            If scale_fn is not None, this argument is ignored.
        gamma: constant in 'exp_range' scaling function:
            gamma**(cycle iterations)
        scale_fn: Custom scaling policy defined by a single
            argument lambda function, where 
            0 <= scale_fn(x) <= 1 for all x >= 0.
            mode paramater is ignored 
        scale_mode: {'cycle', 'iterations'}.
            Defines whether scale_fn is evaluated on 
            cycle number or cycle iterations (training
            iterations since start of cycle). Default is 'cycle'.
    """

    def __init__(self, base_lr=0.001, max_lr=0.006, step_size=2000., mode='triangular',
                 gamma=1., scale_fn=None, scale_mode='cycle'):
        super(CyclicLR, self).__init__()

        self.base_lr = base_lr
        self.max_lr = max_lr
        self.step_size = step_size
        self.mode = mode
        self.gamma = gamma
        if scale_fn == None:
            if self.mode == 'triangular':
                self.scale_fn = lambda x: 1.
                self.scale_mode = 'cycle'
            elif self.mode == 'triangular2':
                self.scale_fn = lambda x: 1/(2.**(x-1))
                self.scale_mode = 'cycle'
            elif self.mode == 'exp_range':
                self.scale_fn = lambda x: gamma**(x)
                self.scale_mode = 'iterations'
        else:
            self.scale_fn = scale_fn
            self.scale_mode = scale_mode
        self.clr_iterations = 0.
        self.trn_iterations = 0.
        self.history = {}

        self._reset()

    def _reset(self, new_base_lr=None, new_max_lr=None,
               new_step_size=None):
        """Resets cycle iterations.
        Optional boundary/step size adjustment.
        """
        if new_base_lr != None:
            self.base_lr = new_base_lr
        if new_max_lr != None:
            self.max_lr = new_max_lr
        if new_step_size != None:
            self.step_size = new_step_size
        self.clr_iterations = 0.
        
    def clr(self):
        cycle = np.floor(1+self.clr_iterations/(2*self.step_size))
        x = np.abs(self.clr_iterations/self.step_size - 2*cycle + 1)
        if self.scale_mode == 'cycle':
            return self.base_lr + (self.max_lr-self.base_lr)*np.maximum(0, (1-x))*self.scale_fn(cycle)
        else:
            return self.base_lr + (self.max_lr-self.base_lr)*np.maximum(0, (1-x))*self.scale_fn(self.clr_iterations)
        
    def on_train_begin(self, logs={}):
        logs = logs or {}

        if self.clr_iterations == 0:
            K.set_value(self.model.optimizer.lr, self.base_lr)
        else:
            K.set_value(self.model.optimizer.lr, self.clr())        
            
    def on_batch_end(self, epoch, logs=None):
        
        logs = logs or {}
        self.trn_iterations += 1
        self.clr_iterations += 1

        self.history.setdefault('lr', []).append(K.get_value(self.model.optimizer.lr))
        self.history.setdefault('iterations', []).append(self.trn_iterations)

        for k, v in logs.items():
            self.history.setdefault(k, []).append(v)
        
        K.set_value(self.model.optimizer.lr, self.clr())

# %%
clr = CyclicLR(base_lr=1e-12, max_lr=.1, step_size=14421)

# %%
history = model.fit_generator(
    generator=train_gen,
    # validation_data=valid_gen,
    epochs=20,
    callbacks=[clr]
)
# Out:
# Epoch 1/20
# 722/722 [==============================] - 151s 209ms/step - loss: 47.4033 - age_output_loss: 1.5023 - bag_output_loss: 0.9968 - bodypose_output_loss: 1.0109 - emotion_output_loss: 1.1324 - footwear_output_loss: 1.0729 - gender_output_loss: 0.6887 - imagequality_output_loss: 1.0494 - weight_output_loss: 1.1521 - age_output_acc: 0.3951 - bag_output_acc: 0.5540 - bodypose_output_acc: 0.6042 - emotion_output_acc: 0.6884 - footwear_output_acc: 0.4340 - gender_output_acc: 0.5493 - imagequality_output_acc: 0.5408 - weight_output_acc: 0.6342
# Epoch 2/20
# 722/722 [==============================] - 138s 192ms/step - loss: 43.8918 - age_output_loss: 1.4262 - bag_output_loss: 0.9188 - bodypose_output_loss: 0.9279 - emotion_output_loss: 0.9115 - footwear_output_loss: 0.9939 - gender_output_loss: 0.6724 - imagequality_output_loss: 0.9485 - weight_output_loss: 0.9813 - age_output_acc: 0.3995 - bag_output_acc: 0.5621 - bodypose_output_acc: 0.6178 - emotion_output_acc: 0.7086 - footwear_output_acc: 0.5525 - gender_output_acc: 0.5675 - imagequality_output_acc: 0.5554 - weight_output_acc: 0.6373
# Epoch 3/20
# 722/722 [==============================] - 138s 192ms/step - loss: 38.8470 - age_output_loss: 1.4178 - bag_output_loss: 0.9037 - bodypose_output_loss: 0.9101 - emotion_output_loss: 0.9100 - footwear_output_loss: 0.9068 - gender_output_loss: 0.6333 - imagequality_output_loss: 0.9036 - weight_output_loss: 0.9799 - age_output_acc: 0.3991 - bag_output_acc: 0.5632 - bodypose_output_acc: 0.6178 - emotion_output_acc: 0.7086 - footwear_output_acc: 0.5917 - gender_output_acc: 0.6262 - imagequality_output_acc: 0.5569 - weight_output_acc: 0.6373
# Epoch 4/20
# 722/722 [==============================] - 139s 192ms/step - loss: 32.6151 - age_output_loss: 1.4066 - bag_output_loss: 0.8992 - bodypose_output_loss: 0.8204 - emotion_output_loss: 0.9081 - footwear_output_loss: 0.8714 - gender_output_loss: 0.6060 - imagequality_output_loss: 0.9004 - weight_output_loss: 0.9783 - age_output_acc: 0.3972 - bag_output_acc: 0.5627 - bodypose_output_acc: 0.6404 - emotion_output_acc: 0.7086 - footwear_output_acc: 0.6087 - gender_output_acc: 0.6612 - imagequality_output_acc: 0.5576 - weight_output_acc: 0.6368
# Epoch 5/20
# 722/722 [==============================] - 138s 192ms/step - loss: 26.1917 - age_output_loss: 1.3966 - bag_output_loss: 0.8900 - bodypose_output_loss: 0.7611 - emotion_output_loss: 0.9093 - footwear_output_loss: 0.8424 - gender_output_loss: 0.5806 - imagequality_output_loss: 0.8933 - weight_output_loss: 0.9735 - age_output_acc: 0.4004 - bag_output_acc: 0.5686 - bodypose_output_acc: 0.6746 - emotion_output_acc: 0.7086 - footwear_output_acc: 0.6235 - gender_output_acc: 0.6916 - imagequality_output_acc: 0.5613 - weight_output_acc: 0.6372
# Epoch 6/20
# 722/722 [==============================] - 138s 191ms/step - loss: 20.3737 - age_output_loss: 1.3852 - bag_output_loss: 0.8828 - bodypose_output_loss: 0.7062 - emotion_output_loss: 0.9031 - footwear_output_loss: 0.8201 - gender_output_loss: 0.5508 - imagequality_output_loss: 0.8910 - weight_output_loss: 0.9672 - age_output_acc: 0.4004 - bag_output_acc: 0.5752 - bodypose_output_acc: 0.6995 - emotion_output_acc: 0.7086 - footwear_output_acc: 0.6316 - gender_output_acc: 0.7154 - imagequality_output_acc: 0.5642 - weight_output_acc: 0.6372
# Epoch 7/20
# 722/722 [==============================] - 138s 191ms/step - loss: 15.6860 - age_output_loss: 1.3796 - bag_output_loss: 0.8761 - bodypose_output_loss: 0.6607 - emotion_output_loss: 0.8991 - footwear_output_loss: 0.8097 - gender_output_loss: 0.5206 - imagequality_output_loss: 0.8903 - weight_output_loss: 0.9620 - age_output_acc: 0.4027 - bag_output_acc: 0.5793 - bodypose_output_acc: 0.7226 - emotion_output_acc: 0.7086 - footwear_output_acc: 0.6438 - gender_output_acc: 0.7412 - imagequality_output_acc: 0.5626 - weight_output_acc: 0.6378
# Epoch 8/20
# 722/722 [==============================] - 139s 192ms/step - loss: 12.2530 - age_output_loss: 1.3743 - bag_output_loss: 0.8659 - bodypose_output_loss: 0.6327 - emotion_output_loss: 0.8946 - footwear_output_loss: 0.7945 - gender_output_loss: 0.4961 - imagequality_output_loss: 0.8867 - weight_output_loss: 0.9569 - age_output_acc: 0.4045 - bag_output_acc: 0.5943 - bodypose_output_acc: 0.7388 - emotion_output_acc: 0.7086 - footwear_output_acc: 0.6470 - gender_output_acc: 0.7569 - imagequality_output_acc: 0.5666 - weight_output_acc: 0.6373
# Epoch 9/20
# 722/722 [==============================] - 139s 192ms/step - loss: 9.9505 - age_output_loss: 1.3659 - bag_output_loss: 0.8595 - bodypose_output_loss: 0.6065 - emotion_output_loss: 0.8889 - footwear_output_loss: 0.7812 - gender_output_loss: 0.4753 - imagequality_output_loss: 0.8799 - weight_output_loss: 0.9532 - age_output_acc: 0.4035 - bag_output_acc: 0.5991 - bodypose_output_acc: 0.7497 - emotion_output_acc: 0.7086 - footwear_output_acc: 0.6603 - gender_output_acc: 0.7696 - imagequality_output_acc: 0.5706 - weight_output_acc: 0.6369
# Epoch 10/20
# 722/722 [==============================] - 139s 192ms/step - loss: 8.5452 - age_output_loss: 1.3566 - bag_output_loss: 0.8549 - bodypose_output_loss: 0.5770 - emotion_output_loss: 0.8861 - footwear_output_loss: 0.7748 - gender_output_loss: 0.4613 - imagequality_output_loss: 0.8761 - weight_output_loss: 0.9457 - age_output_acc: 0.4040 - bag_output_acc: 0.6049 - bodypose_output_acc: 0.7592 - emotion_output_acc: 0.7086 - footwear_output_acc: 0.6627 - gender_output_acc: 0.7806 - imagequality_output_acc: 0.5748 - weight_output_acc: 0.6379
# Epoch 11/20
# 722/722 [==============================] - 139s 193ms/step - loss: 7.7613 - age_output_loss: 1.3505 - bag_output_loss: 0.8496 - bodypose_output_loss: 0.5590 - emotion_output_loss: 0.8827 - footwear_output_loss: 0.7657 - gender_output_loss: 0.4493 - imagequality_output_loss: 0.8721 - weight_output_loss: 0.9405 - age_output_acc: 0.4109 - bag_output_acc: 0.6107 - bodypose_output_acc: 0.7711 - emotion_output_acc: 0.7086 - footwear_output_acc: 0.6648 - gender_output_acc: 0.7857 - imagequality_output_acc: 0.5744 - weight_output_acc: 0.6375
# Epoch 12/20
# 722/722 [==============================] - 139s 193ms/step - loss: 7.3517 - age_output_loss: 1.3432 - bag_output_loss: 0.8434 - bodypose_output_loss: 0.5340 - emotion_output_loss: 0.8796 - footwear_output_loss: 0.7593 - gender_output_loss: 0.4380 - imagequality_output_loss: 0.8741 - weight_output_loss: 0.9355 - age_output_acc: 0.4164 - bag_output_acc: 0.6171 - bodypose_output_acc: 0.7806 - emotion_output_acc: 0.7086 - footwear_output_acc: 0.6670 - gender_output_acc: 0.7930 - imagequality_output_acc: 0.5791 - weight_output_acc: 0.6363
# Epoch 13/20
# 722/722 [==============================] - 139s 193ms/step - loss: 7.1294 - age_output_loss: 1.3292 - bag_output_loss: 0.8358 - bodypose_output_loss: 0.5167 - emotion_output_loss: 0.8757 - footwear_output_loss: 0.7512 - gender_output_loss: 0.4227 - imagequality_output_loss: 0.8666 - weight_output_loss: 0.9301 - age_output_acc: 0.4172 - bag_output_acc: 0.6243 - bodypose_output_acc: 0.7930 - emotion_output_acc: 0.7086 - footwear_output_acc: 0.6723 - gender_output_acc: 0.8031 - imagequality_output_acc: 0.5757 - weight_output_acc: 0.6384
# Epoch 14/20
# 722/722 [==============================] - 139s 192ms/step - loss: 7.0182 - age_output_loss: 1.3146 - bag_output_loss: 0.8283 - bodypose_output_loss: 0.4977 - emotion_output_loss: 0.8691 - footwear_output_loss: 0.7405 - gender_output_loss: 0.4250 - imagequality_output_loss: 0.8573 - weight_output_loss: 0.9230 - age_output_acc: 0.4330 - bag_output_acc: 0.6231 - bodypose_output_acc: 0.8002 - emotion_output_acc: 0.7088 - footwear_output_acc: 0.6717 - gender_output_acc: 0.8014 - imagequality_output_acc: 0.5917 - weight_output_acc: 0.6394
# Epoch 15/20
# 722/722 [==============================] - 139s 193ms/step - loss: 7.0149 - age_output_loss: 1.2954 - bag_output_loss: 0.8253 - bodypose_output_loss: 0.5002 - emotion_output_loss: 0.8660 - footwear_output_loss: 0.7388 - gender_output_loss: 0.4223 - imagequality_output_loss: 0.8582 - weight_output_loss: 0.9172 - age_output_acc: 0.4406 - bag_output_acc: 0.6270 - bodypose_output_acc: 0.7982 - emotion_output_acc: 0.7096 - footwear_output_acc: 0.6750 - gender_output_acc: 0.8068 - imagequality_output_acc: 0.5871 - weight_output_acc: 0.6425
# Epoch 16/20
# 722/722 [==============================] - 139s 192ms/step - loss: 6.9106 - age_output_loss: 1.2763 - bag_output_loss: 0.8167 - bodypose_output_loss: 0.4667 - emotion_output_loss: 0.8548 - footwear_output_loss: 0.7212 - gender_output_loss: 0.4065 - imagequality_output_loss: 0.8414 - weight_output_loss: 0.9048 - age_output_acc: 0.4493 - bag_output_acc: 0.6320 - bodypose_output_acc: 0.8143 - emotion_output_acc: 0.7097 - footwear_output_acc: 0.6851 - gender_output_acc: 0.8138 - imagequality_output_acc: 0.5963 - weight_output_acc: 0.6409
# Epoch 17/20
# 722/722 [==============================] - 139s 193ms/step - loss: 6.8681 - age_output_loss: 1.2488 - bag_output_loss: 0.8123 - bodypose_output_loss: 0.4507 - emotion_output_loss: 0.8458 - footwear_output_loss: 0.7091 - gender_output_loss: 0.4004 - imagequality_output_loss: 0.8322 - weight_output_loss: 0.8898 - age_output_acc: 0.4637 - bag_output_acc: 0.6359 - bodypose_output_acc: 0.8169 - emotion_output_acc: 0.7089 - footwear_output_acc: 0.6864 - gender_output_acc: 0.8202 - imagequality_output_acc: 0.6041 - weight_output_acc: 0.6439
# Epoch 18/20
# 722/722 [==============================] - 139s 193ms/step - loss: 6.8520 - age_output_loss: 1.2217 - bag_output_loss: 0.8047 - bodypose_output_loss: 0.4387 - emotion_output_loss: 0.8339 - footwear_output_loss: 0.6970 - gender_output_loss: 0.4081 - imagequality_output_loss: 0.8207 - weight_output_loss: 0.8779 - age_output_acc: 0.4756 - bag_output_acc: 0.6343 - bodypose_output_acc: 0.8265 - emotion_output_acc: 0.7106 - footwear_output_acc: 0.6919 - gender_output_acc: 0.8111 - imagequality_output_acc: 0.6108 - weight_output_acc: 0.6509
# Epoch 19/20
# 722/722 [==============================] - 139s 193ms/step - loss: 6.8610 - age_output_loss: 1.1948 - bag_output_loss: 0.8087 - bodypose_output_loss: 0.4195 - emotion_output_loss: 0.8149 - footwear_output_loss: 0.6856 - gender_output_loss: 0.4288 - imagequality_output_loss: 0.8054 - weight_output_loss: 0.8630 - age_output_acc: 0.4920 - bag_output_acc: 0.6353 - bodypose_output_acc: 0.8341 - emotion_output_acc: 0.7127 - footwear_output_acc: 0.6986 - gender_output_acc: 0.7973 - imagequality_output_acc: 0.6185 - weight_output_acc: 0.6535
# Epoch 20/20
# 722/722 [==============================] - 139s 193ms/step - loss: 6.7590 - age_output_loss: 1.1678 - bag_output_loss: 0.7862 - bodypose_output_loss: 0.4034 - emotion_output_loss: 0.7943 - footwear_output_loss: 0.6672 - gender_output_loss: 0.4006 - imagequality_output_loss: 0.7892 - weight_output_loss: 0.8505 - age_output_acc: 0.5003 - bag_output_acc: 0.6508 - bodypose_output_acc: 0.8392 - emotion_output_acc: 0.7154 - footwear_output_acc: 0.7146 - gender_output_acc: 0.8191 - imagequality_output_acc: 0.6322 - weight_output_acc: 0.6635

# %%
lr = clr.history['lr']
loss = clr.history['loss']

losses = [
  clr.history['age_output_loss'],
  clr.history['bag_output_loss'],
  clr.history['bodypose_output_loss'],
  clr.history['emotion_output_loss'],
  clr.history['footwear_output_loss'],
  clr.history['gender_output_loss'],
  clr.history['imagequality_output_loss'],
  clr.history['weight_output_loss']
]

import matplotlib.pyplot as plt

print('LR range vs iteration')
plt.plot(range(len(lr)), lr)
plt.show()

print('Loss vs LR')
items=500
plt.plot(lr[:items], loss[:items])
plt.show()

print('Individual Loss vs LR')
for loss in losses:
  plt.plot(lr, loss)
plt.show()
# Out:
# LR range vs iteration
# Loss vs LR
# Individual Loss vs LR

# %%
clr = CyclicLR(base_lr=0.0005, max_lr=0.002, step_size=5000)
history = model.fit_generator(
    generator=train_gen,
    validation_data=valid_gen,
    epochs=20,
    callbacks=[clr]
)
# Out:
# Epoch 1/20
# 721/722 [============================>.] - ETA: 0s - loss: 6.2708 - age_output_loss: 1.0614 - bag_output_loss: 0.7350 - bodypose_output_loss: 0.3351 - emotion_output_loss: 0.7300 - footwear_output_loss: 0.6089 - gender_output_loss: 0.3353 - imagequality_output_loss: 0.7148 - weight_output_loss: 0.8003 - age_output_acc: 0.5676 - bag_output_acc: 0.6705 - bodypose_output_acc: 0.8731 - emotion_output_acc: 0.7296 - footwear_output_acc: 0.7503 - gender_output_acc: 0.8510 - imagequality_output_acc: 0.6744 - weight_output_acc: 0.6801Epoch 1/20
# 722/722 [==============================] - 150s 207ms/step - loss: 6.2695 - age_output_loss: 1.0611 - bag_output_loss: 0.7352 - bodypose_output_loss: 0.3349 - emotion_output_loss: 0.7293 - footwear_output_loss: 0.6089 - gender_output_loss: 0.3353 - imagequality_output_loss: 0.7146 - weight_output_loss: 0.8001 - age_output_acc: 0.5677 - bag_output_acc: 0.6703 - bodypose_output_acc: 0.8732 - emotion_output_acc: 0.7300 - footwear_output_acc: 0.7505 - gender_output_acc: 0.8510 - imagequality_output_acc: 0.6745 - weight_output_acc: 0.6800 - val_loss: 8.4691 - val_age_output_loss: 1.5478 - val_bag_output_loss: 0.8711 - val_bodypose_output_loss: 0.6946 - val_emotion_output_loss: 0.9509 - val_footwear_output_loss: 0.8954 - val_gender_output_loss: 0.4707 - val_imagequality_output_loss: 1.0411 - val_weight_output_loss: 1.0520 - val_age_output_acc: 0.3585 - val_bag_output_acc: 0.6208 - val_bodypose_output_acc: 0.7294 - val_emotion_output_acc: 0.7176 - val_footwear_output_acc: 0.6213 - val_gender_output_acc: 0.7800 - val_imagequality_output_acc: 0.5314 - val_weight_output_acc: 0.5972
# Epoch 2/20
# 721/722 [============================>.] - ETA: 0s - loss: 5.8675 - age_output_loss: 0.9930 - bag_output_loss: 0.6997 - bodypose_output_loss: 0.2615 - emotion_output_loss: 0.6905 - footwear_output_loss: 0.5620 - gender_output_loss: 0.2929 - imagequality_output_loss: 0.6629 - weight_output_loss: 0.7648 - age_output_acc: 0.5973 - bag_output_acc: 0.6913 - bodypose_output_acc: 0.9092 - emotion_output_acc: 0.7370 - footwear_output_acc: 0.7682 - gender_output_acc: 0.8778 - imagequality_output_acc: 0.6999 - weight_output_acc: 0.6903Epoch 1/20
# 722/722 [==============================] - 150s 208ms/step - loss: 5.8667 - age_output_loss: 0.9927 - bag_output_loss: 0.6999 - bodypose_output_loss: 0.2614 - emotion_output_loss: 0.6905 - footwear_output_loss: 0.5618 - gender_output_loss: 0.2929 - imagequality_output_loss: 0.6627 - weight_output_loss: 0.7645 - age_output_acc: 0.5974 - bag_output_acc: 0.6911 - bodypose_output_acc: 0.9092 - emotion_output_acc: 0.7369 - footwear_output_acc: 0.7682 - gender_output_acc: 0.8777 - imagequality_output_acc: 0.7001 - weight_output_acc: 0.6904 - val_loss: 8.4937 - val_age_output_loss: 1.5762 - val_bag_output_loss: 0.8775 - val_bodypose_output_loss: 0.6897 - val_emotion_output_loss: 0.9561 - val_footwear_output_loss: 0.9001 - val_gender_output_loss: 0.4595 - val_imagequality_output_loss: 1.0453 - val_weight_output_loss: 1.0551 - val_age_output_acc: 0.3487 - val_bag_output_acc: 0.6198 - val_bodypose_output_acc: 0.7333 - val_emotion_output_acc: 0.7151 - val_footwear_output_acc: 0.6213 - val_gender_output_acc: 0.7962 - val_imagequality_output_acc: 0.5270 - val_weight_output_acc: 0.6012
# Epoch 3/20
# 721/722 [============================>.] - ETA: 0s - loss: 5.5894 - age_output_loss: 0.9380 - bag_output_loss: 0.6741 - bodypose_output_loss: 0.2262 - emotion_output_loss: 0.6644 - footwear_output_loss: 0.5291 - gender_output_loss: 0.2644 - imagequality_output_loss: 0.6297 - weight_output_loss: 0.7359 - age_output_acc: 0.6200 - bag_output_acc: 0.7056 - bodypose_output_acc: 0.9212 - emotion_output_acc: 0.7436 - footwear_output_acc: 0.7785 - gender_output_acc: 0.8913 - imagequality_output_acc: 0.7202 - weight_output_acc: 0.7032Epoch 1/20
# 722/722 [==============================] - 148s 205ms/step - loss: 5.5900 - age_output_loss: 0.9381 - bag_output_loss: 0.6740 - bodypose_output_loss: 0.2262 - emotion_output_loss: 0.6646 - footwear_output_loss: 0.5290 - gender_output_loss: 0.2644 - imagequality_output_loss: 0.6296 - weight_output_loss: 0.7364 - age_output_acc: 0.6199 - bag_output_acc: 0.7055 - bodypose_output_acc: 0.9211 - emotion_output_acc: 0.7435 - footwear_output_acc: 0.7785 - gender_output_acc: 0.8914 - imagequality_output_acc: 0.7201 - weight_output_acc: 0.7030 - val_loss: 8.8051 - val_age_output_loss: 1.7239 - val_bag_output_loss: 0.8768 - val_bodypose_output_loss: 0.7144 - val_emotion_output_loss: 0.9941 - val_footwear_output_loss: 0.9375 - val_gender_output_loss: 0.4671 - val_imagequality_output_loss: 1.0776 - val_weight_output_loss: 1.0932 - val_age_output_acc: 0.3414 - val_bag_output_acc: 0.6174 - val_bodypose_output_acc: 0.7441 - val_emotion_output_acc: 0.7078 - val_footwear_output_acc: 0.6297 - val_gender_output_acc: 0.7942 - val_imagequality_output_acc: 0.5285 - val_weight_output_acc: 0.5889
# Epoch 4/20
# 721/722 [============================>.] - ETA: 0s - loss: 5.3409 - age_output_loss: 0.8873 - bag_output_loss: 0.6531 - bodypose_output_loss: 0.1985 - emotion_output_loss: 0.6396 - footwear_output_loss: 0.4982 - gender_output_loss: 0.2417 - imagequality_output_loss: 0.6006 - weight_output_loss: 0.7092 - age_output_acc: 0.6401 - bag_output_acc: 0.7145 - bodypose_output_acc: 0.9318 - emotion_output_acc: 0.7541 - footwear_output_acc: 0.7951 - gender_output_acc: 0.9011 - imagequality_output_acc: 0.7334 - weight_output_acc: 0.7153Epoch 1/20
# 722/722 [==============================] - 148s 205ms/step - loss: 5.3411 - age_output_loss: 0.8871 - bag_output_loss: 0.6536 - bodypose_output_loss: 0.1985 - emotion_output_loss: 0.6396 - footwear_output_loss: 0.4984 - gender_output_loss: 0.2416 - imagequality_output_loss: 0.6009 - weight_output_loss: 0.7089 - age_output_acc: 0.6404 - bag_output_acc: 0.7142 - bodypose_output_acc: 0.9317 - emotion_output_acc: 0.7541 - footwear_output_acc: 0.7950 - gender_output_acc: 0.9010 - imagequality_output_acc: 0.7331 - weight_output_acc: 0.7155 - val_loss: 9.1619 - val_age_output_loss: 1.7929 - val_bag_output_loss: 0.9055 - val_bodypose_output_loss: 0.7568 - val_emotion_output_loss: 1.0333 - val_footwear_output_loss: 0.9866 - val_gender_output_loss: 0.4739 - val_imagequality_output_loss: 1.1917 - val_weight_output_loss: 1.1171 - val_age_output_acc: 0.3335 - val_bag_output_acc: 0.6149 - val_bodypose_output_acc: 0.7377 - val_emotion_output_acc: 0.6979 - val_footwear_output_acc: 0.6213 - val_gender_output_acc: 0.8060 - val_imagequality_output_acc: 0.5069 - val_weight_output_acc: 0.5830
# Epoch 5/20
# 721/722 [============================>.] - ETA: 0s - loss: 5.1249 - age_output_loss: 0.8440 - bag_output_loss: 0.6337 - bodypose_output_loss: 0.1773 - emotion_output_loss: 0.6123 - footwear_output_loss: 0.4718 - gender_output_loss: 0.2260 - imagequality_output_loss: 0.5781 - weight_output_loss: 0.6867 - age_output_acc: 0.6596 - bag_output_acc: 0.7270 - bodypose_output_acc: 0.9389 - emotion_output_acc: 0.7643 - footwear_output_acc: 0.8064 - gender_output_acc: 0.9083 - imagequality_output_acc: 0.7495 - weight_output_acc: 0.7250Epoch 1/20
# 722/722 [==============================] - 148s 205ms/step - loss: 5.1237 - age_output_loss: 0.8440 - bag_output_loss: 0.6339 - bodypose_output_loss: 0.1771 - emotion_output_loss: 0.6119 - footwear_output_loss: 0.4714 - gender_output_loss: 0.2258 - imagequality_output_loss: 0.5779 - weight_output_loss: 0.6866 - age_output_acc: 0.6595 - bag_output_acc: 0.7268 - bodypose_output_acc: 0.9390 - emotion_output_acc: 0.7645 - footwear_output_acc: 0.8065 - gender_output_acc: 0.9084 - imagequality_output_acc: 0.7497 - weight_output_acc: 0.7250 - val_loss: 9.1627 - val_age_output_loss: 1.7924 - val_bag_output_loss: 0.9075 - val_bodypose_output_loss: 0.7572 - val_emotion_output_loss: 1.0343 - val_footwear_output_loss: 0.9957 - val_gender_output_loss: 0.4681 - val_imagequality_output_loss: 1.1911 - val_weight_output_loss: 1.1309 - val_age_output_acc: 0.3325 - val_bag_output_acc: 0.6194 - val_bodypose_output_acc: 0.7441 - val_emotion_output_acc: 0.6960 - val_footwear_output_acc: 0.6257 - val_gender_output_acc: 0.8075 - val_imagequality_output_acc: 0.5113 - val_weight_output_acc: 0.5825
# Epoch 6/20
# 721/722 [============================>.] - ETA: 0s - loss: 4.9150 - age_output_loss: 0.8057 - bag_output_loss: 0.6189 - bodypose_output_loss: 0.1579 - emotion_output_loss: 0.5907 - footwear_output_loss: 0.4464 - gender_output_loss: 0.2091 - imagequality_output_loss: 0.5517 - weight_output_loss: 0.6595 - age_output_acc: 0.6739 - bag_output_acc: 0.7371 - bodypose_output_acc: 0.9465 - emotion_output_acc: 0.7748 - footwear_output_acc: 0.8190 - gender_output_acc: 0.9164 - imagequality_output_acc: 0.7636 - weight_output_acc: 0.7341Epoch 1/20
# 722/722 [==============================] - 148s 205ms/step - loss: 4.9144 - age_output_loss: 0.8056 - bag_output_loss: 0.6188 - bodypose_output_loss: 0.1581 - emotion_output_loss: 0.5904 - footwear_output_loss: 0.4462 - gender_output_loss: 0.2091 - imagequality_output_loss: 0.5517 - weight_output_loss: 0.6593 - age_output_acc: 0.6740 - bag_output_acc: 0.7371 - bodypose_output_acc: 0.9463 - emotion_output_acc: 0.7749 - footwear_output_acc: 0.8191 - gender_output_acc: 0.9164 - imagequality_output_acc: 0.7635 - weight_output_acc: 0.7342 - val_loss: 9.3202 - val_age_output_loss: 1.8372 - val_bag_output_loss: 0.9302 - val_bodypose_output_loss: 0.7965 - val_emotion_output_loss: 1.0605 - val_footwear_output_loss: 1.0246 - val_gender_output_loss: 0.4833 - val_imagequality_output_loss: 1.1660 - val_weight_output_loss: 1.1573 - val_age_output_acc: 0.3404 - val_bag_output_acc: 0.6208 - val_bodypose_output_acc: 0.7362 - val_emotion_output_acc: 0.6925 - val_footwear_output_acc: 0.6154 - val_gender_output_acc: 0.8040 - val_imagequality_output_acc: 0.5015 - val_weight_output_acc: 0.5742
# Epoch 7/20
# 721/722 [============================>.] - ETA: 0s - loss: 4.7065 - age_output_loss: 0.7648 - bag_output_loss: 0.5980 - bodypose_output_loss: 0.1431 - emotion_output_loss: 0.5645 - footwear_output_loss: 0.4218 - gender_output_loss: 0.1979 - imagequality_output_loss: 0.5303 - weight_output_loss: 0.6330 - age_output_acc: 0.6911 - bag_output_acc: 0.7433 - bodypose_output_acc: 0.9514 - emotion_output_acc: 0.7847 - footwear_output_acc: 0.8301 - gender_output_acc: 0.9217 - imagequality_output_acc: 0.7732 - weight_output_acc: 0.7452Epoch 1/20
# 722/722 [==============================] - 148s 205ms/step - loss: 4.7065 - age_output_loss: 0.7647 - bag_output_loss: 0.5980 - bodypose_output_loss: 0.1431 - emotion_output_loss: 0.5642 - footwear_output_loss: 0.4220 - gender_output_loss: 0.1983 - imagequality_output_loss: 0.5300 - weight_output_loss: 0.6330 - age_output_acc: 0.6910 - bag_output_acc: 0.7433 - bodypose_output_acc: 0.9515 - emotion_output_acc: 0.7849 - footwear_output_acc: 0.8301 - gender_output_acc: 0.9214 - imagequality_output_acc: 0.7733 - weight_output_acc: 0.7451 - val_loss: 9.7495 - val_age_output_loss: 1.9511 - val_bag_output_loss: 0.9480 - val_bodypose_output_loss: 0.8722 - val_emotion_output_loss: 1.1154 - val_footwear_output_loss: 1.0745 - val_gender_output_loss: 0.5001 - val_imagequality_output_loss: 1.2453 - val_weight_output_loss: 1.2013 - val_age_output_acc: 0.3428 - val_bag_output_acc: 0.6174 - val_bodypose_output_acc: 0.7485 - val_emotion_output_acc: 0.6547 - val_footwear_output_acc: 0.6198 - val_gender_output_acc: 0.8075 - val_imagequality_output_acc: 0.5049 - val_weight_output_acc: 0.5658
# Epoch 8/20
# 721/722 [============================>.] - ETA: 0s - loss: 4.5125 - age_output_loss: 0.7344 - bag_output_loss: 0.5831 - bodypose_output_loss: 0.1282 - emotion_output_loss: 0.5387 - footwear_output_loss: 0.4022 - gender_output_loss: 0.1829 - imagequality_output_loss: 0.5052 - weight_output_loss: 0.6073 - age_output_acc: 0.7047 - bag_output_acc: 0.7564 - bodypose_output_acc: 0.9572 - emotion_output_acc: 0.7939 - footwear_output_acc: 0.8404 - gender_output_acc: 0.9280 - imagequality_output_acc: 0.7861 - weight_output_acc: 0.7572Epoch 1/20
# 722/722 [==============================] - 148s 205ms/step - loss: 4.5118 - age_output_loss: 0.7341 - bag_output_loss: 0.5828 - bodypose_output_loss: 0.1281 - emotion_output_loss: 0.5391 - footwear_output_loss: 0.4022 - gender_output_loss: 0.1829 - imagequality_output_loss: 0.5052 - weight_output_loss: 0.6070 - age_output_acc: 0.7049 - bag_output_acc: 0.7566 - bodypose_output_acc: 0.9573 - emotion_output_acc: 0.7936 - footwear_output_acc: 0.8403 - gender_output_acc: 0.9281 - imagequality_output_acc: 0.7862 - weight_output_acc: 0.7573 - val_loss: 9.8288 - val_age_output_loss: 2.0086 - val_bag_output_loss: 0.9569 - val_bodypose_output_loss: 0.8495 - val_emotion_output_loss: 1.1266 - val_footwear_output_loss: 1.0955 - val_gender_output_loss: 0.4969 - val_imagequality_output_loss: 1.2514 - val_weight_output_loss: 1.2236 - val_age_output_acc: 0.3458 - val_bag_output_acc: 0.6144 - val_bodypose_output_acc: 0.7412 - val_emotion_output_acc: 0.6739 - val_footwear_output_acc: 0.6071 - val_gender_output_acc: 0.8065 - val_imagequality_output_acc: 0.4951 - val_weight_output_acc: 0.5624
# Epoch 9/20
# 721/722 [============================>.] - ETA: 0s - loss: 4.3450 - age_output_loss: 0.7067 - bag_output_loss: 0.5645 - bodypose_output_loss: 0.1161 - emotion_output_loss: 0.5172 - footwear_output_loss: 0.3819 - gender_output_loss: 0.1777 - imagequality_output_loss: 0.4863 - weight_output_loss: 0.5844 - age_output_acc: 0.7183 - bag_output_acc: 0.7626 - bodypose_output_acc: 0.9626 - emotion_output_acc: 0.8039 - footwear_output_acc: 0.8518 - gender_output_acc: 0.9351 - imagequality_output_acc: 0.7977 - weight_output_acc: 0.7697Epoch 1/20
# 722/722 [==============================] - 148s 205ms/step - loss: 4.3441 - age_output_loss: 0.7066 - bag_output_loss: 0.5644 - bodypose_output_loss: 0.1161 - emotion_output_loss: 0.5170 - footwear_output_loss: 0.3818 - gender_output_loss: 0.1775 - imagequality_output_loss: 0.4863 - weight_output_loss: 0.5842 - age_output_acc: 0.7184 - bag_output_acc: 0.7626 - bodypose_output_acc: 0.9626 - emotion_output_acc: 0.8039 - footwear_output_acc: 0.8520 - gender_output_acc: 0.9352 - imagequality_output_acc: 0.7976 - weight_output_acc: 0.7697 - val_loss: 10.2111 - val_age_output_loss: 2.0504 - val_bag_output_loss: 0.9783 - val_bodypose_output_loss: 0.8872 - val_emotion_output_loss: 1.1486 - val_footwear_output_loss: 1.1576 - val_gender_output_loss: 0.5191 - val_imagequality_output_loss: 1.3944 - val_weight_output_loss: 1.2745 - val_age_output_acc: 0.3364 - val_bag_output_acc: 0.6076 - val_bodypose_output_acc: 0.7441 - val_emotion_output_acc: 0.6606 - val_footwear_output_acc: 0.6164 - val_gender_output_acc: 0.8050 - val_imagequality_output_acc: 0.4985 - val_weight_output_acc: 0.5634
# Epoch 10/20
# 721/722 [============================>.] - ETA: 0s - loss: 4.1824 - age_output_loss: 0.6765 - bag_output_loss: 0.5494 - bodypose_output_loss: 0.1086 - emotion_output_loss: 0.4962 - footwear_output_loss: 0.3672 - gender_output_loss: 0.1607 - imagequality_output_loss: 0.4664 - weight_output_loss: 0.5647 - age_output_acc: 0.7301 - bag_output_acc: 0.7702 - bodypose_output_acc: 0.9652 - emotion_output_acc: 0.8145 - footwear_output_acc: 0.8557 - gender_output_acc: 0.9407 - imagequality_output_acc: 0.8072 - weight_output_acc: 0.7743Epoch 1/20
# 722/722 [==============================] - 148s 205ms/step - loss: 4.1818 - age_output_loss: 0.6767 - bag_output_loss: 0.5492 - bodypose_output_loss: 0.1085 - emotion_output_loss: 0.4959 - footwear_output_loss: 0.3673 - gender_output_loss: 0.1606 - imagequality_output_loss: 0.4667 - weight_output_loss: 0.5643 - age_output_acc: 0.7301 - bag_output_acc: 0.7700 - bodypose_output_acc: 0.9652 - emotion_output_acc: 0.8146 - footwear_output_acc: 0.8557 - gender_output_acc: 0.9408 - imagequality_output_acc: 0.8069 - weight_output_acc: 0.7746 - val_loss: 10.2342 - val_age_output_loss: 2.1470 - val_bag_output_loss: 0.9832 - val_bodypose_output_loss: 0.8987 - val_emotion_output_loss: 1.1946 - val_footwear_output_loss: 1.1701 - val_gender_output_loss: 0.5136 - val_imagequality_output_loss: 1.2824 - val_weight_output_loss: 1.2597 - val_age_output_acc: 0.3330 - val_bag_output_acc: 0.6154 - val_bodypose_output_acc: 0.7436 - val_emotion_output_acc: 0.6542 - val_footwear_output_acc: 0.6110 - val_gender_output_acc: 0.8094 - val_imagequality_output_acc: 0.4897 - val_weight_output_acc: 0.5648
# Epoch 11/20
# 721/722 [============================>.] - ETA: 0s - loss: 4.0429 - age_output_loss: 0.6521 - bag_output_loss: 0.5357 - bodypose_output_loss: 0.0981 - emotion_output_loss: 0.4789 - footwear_output_loss: 0.3511 - gender_output_loss: 0.1522 - imagequality_output_loss: 0.4502 - weight_output_loss: 0.5466 - age_output_acc: 0.7428 - bag_output_acc: 0.7783 - bodypose_output_acc: 0.9693 - emotion_output_acc: 0.8208 - footwear_output_acc: 0.8642 - gender_output_acc: 0.9416 - imagequality_output_acc: 0.8155 - weight_output_acc: 0.7846Epoch 1/20
# 722/722 [==============================] - 148s 205ms/step - loss: 4.0432 - age_output_loss: 0.6521 - bag_output_loss: 0.5358 - bodypose_output_loss: 0.0980 - emotion_output_loss: 0.4789 - footwear_output_loss: 0.3513 - gender_output_loss: 0.1522 - imagequality_output_loss: 0.4502 - weight_output_loss: 0.5467 - age_output_acc: 0.7427 - bag_output_acc: 0.7785 - bodypose_output_acc: 0.9693 - emotion_output_acc: 0.8208 - footwear_output_acc: 0.8642 - gender_output_acc: 0.9415 - imagequality_output_acc: 0.8155 - weight_output_acc: 0.7845 - val_loss: 10.5423 - val_age_output_loss: 2.1715 - val_bag_output_loss: 1.0068 - val_bodypose_output_loss: 0.9400 - val_emotion_output_loss: 1.2195 - val_footwear_output_loss: 1.2102 - val_gender_output_loss: 0.5434 - val_imagequality_output_loss: 1.3699 - val_weight_output_loss: 1.3096 - val_age_output_acc: 0.3394 - val_bag_output_acc: 0.6090 - val_bodypose_output_acc: 0.7382 - val_emotion_output_acc: 0.6582 - val_footwear_output_acc: 0.6095 - val_gender_output_acc: 0.8050 - val_imagequality_output_acc: 0.4990 - val_weight_output_acc: 0.5604
# Epoch 12/20
# 721/722 [============================>.] - ETA: 0s - loss: 3.9310 - age_output_loss: 0.6338 - bag_output_loss: 0.5237 - bodypose_output_loss: 0.0925 - emotion_output_loss: 0.4635 - footwear_output_loss: 0.3410 - gender_output_loss: 0.1425 - imagequality_output_loss: 0.4344 - weight_output_loss: 0.5338 - age_output_acc: 0.7503 - bag_output_acc: 0.7838 - bodypose_output_acc: 0.9727 - emotion_output_acc: 0.8261 - footwear_output_acc: 0.8681 - gender_output_acc: 0.9491 - imagequality_output_acc: 0.8209 - weight_output_acc: 0.7899Epoch 1/20
# 722/722 [==============================] - 147s 204ms/step - loss: 3.9312 - age_output_loss: 0.6340 - bag_output_loss: 0.5238 - bodypose_output_loss: 0.0924 - emotion_output_loss: 0.4633 - footwear_output_loss: 0.3410 - gender_output_loss: 0.1428 - imagequality_output_loss: 0.4341 - weight_output_loss: 0.5339 - age_output_acc: 0.7501 - bag_output_acc: 0.7836 - bodypose_output_acc: 0.9727 - emotion_output_acc: 0.8261 - footwear_output_acc: 0.8681 - gender_output_acc: 0.9490 - imagequality_output_acc: 0.8210 - weight_output_acc: 0.7899 - val_loss: 10.6487 - val_age_output_loss: 2.1701 - val_bag_output_loss: 0.9987 - val_bodypose_output_loss: 0.9638 - val_emotion_output_loss: 1.2404 - val_footwear_output_loss: 1.2315 - val_gender_output_loss: 0.5468 - val_imagequality_output_loss: 1.4149 - val_weight_output_loss: 1.3218 - val_age_output_acc: 0.3325 - val_bag_output_acc: 0.6081 - val_bodypose_output_acc: 0.7417 - val_emotion_output_acc: 0.6493 - val_footwear_output_acc: 0.6100 - val_gender_output_acc: 0.8094 - val_imagequality_output_acc: 0.4951 - val_weight_output_acc: 0.5629
# Epoch 13/20
# 721/722 [============================>.] - ETA: 0s - loss: 3.8428 - age_output_loss: 0.6163 - bag_output_loss: 0.5145 - bodypose_output_loss: 0.0891 - emotion_output_loss: 0.4532 - footwear_output_loss: 0.3311 - gender_output_loss: 0.1371 - imagequality_output_loss: 0.4258 - weight_output_loss: 0.5194 - age_output_acc: 0.7599 - bag_output_acc: 0.7886 - bodypose_output_acc: 0.9735 - emotion_output_acc: 0.8320 - footwear_output_acc: 0.8727 - gender_output_acc: 0.9509 - imagequality_output_acc: 0.8262 - weight_output_acc: 0.7967Epoch 1/20
# 722/722 [==============================] - 148s 205ms/step - loss: 3.8424 - age_output_loss: 0.6161 - bag_output_loss: 0.5148 - bodypose_output_loss: 0.0891 - emotion_output_loss: 0.4530 - footwear_output_loss: 0.3309 - gender_output_loss: 0.1372 - imagequality_output_loss: 0.4257 - weight_output_loss: 0.5195 - age_output_acc: 0.7598 - bag_output_acc: 0.7885 - bodypose_output_acc: 0.9735 - emotion_output_acc: 0.8320 - footwear_output_acc: 0.8728 - gender_output_acc: 0.9509 - imagequality_output_acc: 0.8262 - weight_output_acc: 0.7966 - val_loss: 10.5892 - val_age_output_loss: 2.2077 - val_bag_output_loss: 0.9956 - val_bodypose_output_loss: 0.9367 - val_emotion_output_loss: 1.2378 - val_footwear_output_loss: 1.2388 - val_gender_output_loss: 0.5313 - val_imagequality_output_loss: 1.3719 - val_weight_output_loss: 1.3174 - val_age_output_acc: 0.3310 - val_bag_output_acc: 0.6125 - val_bodypose_output_acc: 0.7412 - val_emotion_output_acc: 0.6572 - val_footwear_output_acc: 0.6081 - val_gender_output_acc: 0.8089 - val_imagequality_output_acc: 0.4966 - val_weight_output_acc: 0.5624
# Epoch 14/20
# 721/722 [============================>.] - ETA: 0s - loss: 3.7706 - age_output_loss: 0.6046 - bag_output_loss: 0.5079 - bodypose_output_loss: 0.0849 - emotion_output_loss: 0.4432 - footwear_output_loss: 0.3222 - gender_output_loss: 0.1340 - imagequality_output_loss: 0.4159 - weight_output_loss: 0.5091 - age_output_acc: 0.7662 - bag_output_acc: 0.7901 - bodypose_output_acc: 0.9753 - emotion_output_acc: 0.8345 - footwear_output_acc: 0.8747 - gender_output_acc: 0.9506 - imagequality_output_acc: 0.8317 - weight_output_acc: 0.8002Epoch 1/20
# 722/722 [==============================] - 147s 204ms/step - loss: 3.7712 - age_output_loss: 0.6052 - bag_output_loss: 0.5081 - bodypose_output_loss: 0.0850 - emotion_output_loss: 0.4431 - footwear_output_loss: 0.3221 - gender_output_loss: 0.1342 - imagequality_output_loss: 0.4157 - weight_output_loss: 0.5090 - age_output_acc: 0.7660 - bag_output_acc: 0.7902 - bodypose_output_acc: 0.9752 - emotion_output_acc: 0.8344 - footwear_output_acc: 0.8748 - gender_output_acc: 0.9505 - imagequality_output_acc: 0.8318 - weight_output_acc: 0.8002 - val_loss: 11.0401 - val_age_output_loss: 2.3295 - val_bag_output_loss: 1.0361 - val_bodypose_output_loss: 0.9867 - val_emotion_output_loss: 1.3008 - val_footwear_output_loss: 1.2935 - val_gender_output_loss: 0.5546 - val_imagequality_output_loss: 1.4188 - val_weight_output_loss: 1.3744 - val_age_output_acc: 0.3399 - val_bag_output_acc: 0.6046 - val_bodypose_output_acc: 0.7343 - val_emotion_output_acc: 0.6518 - val_footwear_output_acc: 0.6061 - val_gender_output_acc: 0.8035 - val_imagequality_output_acc: 0.4946 - val_weight_output_acc: 0.5550
# Epoch 15/20
# 721/722 [============================>.] - ETA: 0s - loss: 3.7242 - age_output_loss: 0.5961 - bag_output_loss: 0.5067 - bodypose_output_loss: 0.0837 - emotion_output_loss: 0.4349 - footwear_output_loss: 0.3193 - gender_output_loss: 0.1297 - imagequality_output_loss: 0.4083 - weight_output_loss: 0.5028 - age_output_acc: 0.7684 - bag_output_acc: 0.7941 - bodypose_output_acc: 0.9759 - emotion_output_acc: 0.8369 - footwear_output_acc: 0.8790 - gender_output_acc: 0.9534 - imagequality_output_acc: 0.8338 - weight_output_acc: 0.8036Epoch 1/20
# 722/722 [==============================] - 149s 206ms/step - loss: 3.7252 - age_output_loss: 0.5962 - bag_output_loss: 0.5067 - bodypose_output_loss: 0.0837 - emotion_output_loss: 0.4354 - footwear_output_loss: 0.3196 - gender_output_loss: 0.1299 - imagequality_output_loss: 0.4081 - weight_output_loss: 0.5029 - age_output_acc: 0.7684 - bag_output_acc: 0.7940 - bodypose_output_acc: 0.9759 - emotion_output_acc: 0.8367 - footwear_output_acc: 0.8788 - gender_output_acc: 0.9532 - imagequality_output_acc: 0.8339 - weight_output_acc: 0.8036 - val_loss: 11.0011 - val_age_output_loss: 2.3753 - val_bag_output_loss: 0.9981 - val_bodypose_output_loss: 0.9692 - val_emotion_output_loss: 1.2928 - val_footwear_output_loss: 1.2654 - val_gender_output_loss: 0.5689 - val_imagequality_output_loss: 1.3931 - val_weight_output_loss: 1.3992 - val_age_output_acc: 0.3301 - val_bag_output_acc: 0.6031 - val_bodypose_output_acc: 0.7402 - val_emotion_output_acc: 0.6542 - val_footwear_output_acc: 0.6017 - val_gender_output_acc: 0.7972 - val_imagequality_output_acc: 0.4975 - val_weight_output_acc: 0.5604
# Epoch 16/20
# 721/722 [============================>.] - ETA: 0s - loss: 3.6682 - age_output_loss: 0.5861 - bag_output_loss: 0.4981 - bodypose_output_loss: 0.0808 - emotion_output_loss: 0.4311 - footwear_output_loss: 0.3130 - gender_output_loss: 0.1293 - imagequality_output_loss: 0.4012 - weight_output_loss: 0.4938 - age_output_acc: 0.7735 - bag_output_acc: 0.7963 - bodypose_output_acc: 0.9760 - emotion_output_acc: 0.8373 - footwear_output_acc: 0.8799 - gender_output_acc: 0.9542 - imagequality_output_acc: 0.8393 - weight_output_acc: 0.8081Epoch 1/20
# 722/722 [==============================] - 148s 205ms/step - loss: 3.6678 - age_output_loss: 0.5860 - bag_output_loss: 0.4983 - bodypose_output_loss: 0.0807 - emotion_output_loss: 0.4307 - footwear_output_loss: 0.3131 - gender_output_loss: 0.1294 - imagequality_output_loss: 0.4009 - weight_output_loss: 0.4938 - age_output_acc: 0.7737 - bag_output_acc: 0.7961 - bodypose_output_acc: 0.9760 - emotion_output_acc: 0.8375 - footwear_output_acc: 0.8798 - gender_output_acc: 0.9542 - imagequality_output_acc: 0.8394 - weight_output_acc: 0.8082 - val_loss: 11.5093 - val_age_output_loss: 2.3716 - val_bag_output_loss: 1.0778 - val_bodypose_output_loss: 1.0131 - val_emotion_output_loss: 1.3169 - val_footwear_output_loss: 1.3139 - val_gender_output_loss: 0.6150 - val_imagequality_output_loss: 1.6763 - val_weight_output_loss: 1.3943 - val_age_output_acc: 0.3409 - val_bag_output_acc: 0.6090 - val_bodypose_output_acc: 0.7372 - val_emotion_output_acc: 0.6483 - val_footwear_output_acc: 0.6051 - val_gender_output_acc: 0.8006 - val_imagequality_output_acc: 0.4882 - val_weight_output_acc: 0.5609
# Epoch 17/20
# 721/722 [============================>.] - ETA: 0s - loss: 3.5918 - age_output_loss: 0.5730 - bag_output_loss: 0.4911 - bodypose_output_loss: 0.0755 - emotion_output_loss: 0.4257 - footwear_output_loss: 0.3049 - gender_output_loss: 0.1212 - imagequality_output_loss: 0.3917 - weight_output_loss: 0.4837 - age_output_acc: 0.7782 - bag_output_acc: 0.8009 - bodypose_output_acc: 0.9784 - emotion_output_acc: 0.8423 - footwear_output_acc: 0.8824 - gender_output_acc: 0.9575 - imagequality_output_acc: 0.8456 - weight_output_acc: 0.8114Epoch 1/20
# 722/722 [==============================] - 148s 205ms/step - loss: 3.5910 - age_output_loss: 0.5730 - bag_output_loss: 0.4909 - bodypose_output_loss: 0.0755 - emotion_output_loss: 0.4256 - footwear_output_loss: 0.3046 - gender_output_loss: 0.1212 - imagequality_output_loss: 0.3917 - weight_output_loss: 0.4836 - age_output_acc: 0.7783 - bag_output_acc: 0.8009 - bodypose_output_acc: 0.9784 - emotion_output_acc: 0.8422 - footwear_output_acc: 0.8826 - gender_output_acc: 0.9574 - imagequality_output_acc: 0.8456 - weight_output_acc: 0.8114 - val_loss: 11.2522 - val_age_output_loss: 2.3468 - val_bag_output_loss: 1.0658 - val_bodypose_output_loss: 1.0115 - val_emotion_output_loss: 1.3159 - val_footwear_output_loss: 1.3280 - val_gender_output_loss: 0.5916 - val_imagequality_output_loss: 1.4615 - val_weight_output_loss: 1.4117 - val_age_output_acc: 0.3340 - val_bag_output_acc: 0.6017 - val_bodypose_output_acc: 0.7367 - val_emotion_output_acc: 0.6478 - val_footwear_output_acc: 0.5977 - val_gender_output_acc: 0.7962 - val_imagequality_output_acc: 0.4951 - val_weight_output_acc: 0.5555
# Epoch 18/20
# 721/722 [============================>.] - ETA: 0s - loss: 3.4999 - age_output_loss: 0.5571 - bag_output_loss: 0.4810 - bodypose_output_loss: 0.0719 - emotion_output_loss: 0.4107 - footwear_output_loss: 0.2971 - gender_output_loss: 0.1175 - imagequality_output_loss: 0.3786 - weight_output_loss: 0.4728 - age_output_acc: 0.7812 - bag_output_acc: 0.8070 - bodypose_output_acc: 0.9803 - emotion_output_acc: 0.8473 - footwear_output_acc: 0.8896 - gender_output_acc: 0.9581 - imagequality_output_acc: 0.8497 - weight_output_acc: 0.8172Epoch 1/20
# 722/722 [==============================] - 148s 204ms/step - loss: 3.5003 - age_output_loss: 0.5571 - bag_output_loss: 0.4814 - bodypose_output_loss: 0.0721 - emotion_output_loss: 0.4108 - footwear_output_loss: 0.2971 - gender_output_loss: 0.1174 - imagequality_output_loss: 0.3784 - weight_output_loss: 0.4727 - age_output_acc: 0.7811 - bag_output_acc: 0.8068 - bodypose_output_acc: 0.9802 - emotion_output_acc: 0.8473 - footwear_output_acc: 0.8897 - gender_output_acc: 0.9581 - imagequality_output_acc: 0.8498 - weight_output_acc: 0.8172 - val_loss: 11.4492 - val_age_output_loss: 2.4406 - val_bag_output_loss: 1.0700 - val_bodypose_output_loss: 1.0223 - val_emotion_output_loss: 1.3709 - val_footwear_output_loss: 1.3720 - val_gender_output_loss: 0.5849 - val_imagequality_output_loss: 1.4437 - val_weight_output_loss: 1.4382 - val_age_output_acc: 0.3237 - val_bag_output_acc: 0.6046 - val_bodypose_output_acc: 0.7323 - val_emotion_output_acc: 0.6434 - val_footwear_output_acc: 0.5997 - val_gender_output_acc: 0.8060 - val_imagequality_output_acc: 0.4907 - val_weight_output_acc: 0.5535
# Epoch 19/20
# 721/722 [============================>.] - ETA: 0s - loss: 3.3948 - age_output_loss: 0.5392 - bag_output_loss: 0.4693 - bodypose_output_loss: 0.0690 - emotion_output_loss: 0.3954 - footwear_output_loss: 0.2840 - gender_output_loss: 0.1145 - imagequality_output_loss: 0.3669 - weight_output_loss: 0.4570 - age_output_acc: 0.7920 - bag_output_acc: 0.8116 - bodypose_output_acc: 0.9809 - emotion_output_acc: 0.8543 - footwear_output_acc: 0.8921 - gender_output_acc: 0.9599 - imagequality_output_acc: 0.8532 - weight_output_acc: 0.8230Epoch 1/20
# 722/722 [==============================] - 147s 204ms/step - loss: 3.3942 - age_output_loss: 0.5394 - bag_output_loss: 0.4691 - bodypose_output_loss: 0.0689 - emotion_output_loss: 0.3953 - footwear_output_loss: 0.2838 - gender_output_loss: 0.1144 - imagequality_output_loss: 0.3668 - weight_output_loss: 0.4569 - age_output_acc: 0.7920 - bag_output_acc: 0.8117 - bodypose_output_acc: 0.9809 - emotion_output_acc: 0.8544 - footwear_output_acc: 0.8923 - gender_output_acc: 0.9600 - imagequality_output_acc: 0.8533 - weight_output_acc: 0.8229 - val_loss: 11.5844 - val_age_output_loss: 2.4603 - val_bag_output_loss: 1.0523 - val_bodypose_output_loss: 1.0267 - val_emotion_output_loss: 1.3654 - val_footwear_output_loss: 1.3799 - val_gender_output_loss: 0.5894 - val_imagequality_output_loss: 1.5600 - val_weight_output_loss: 1.4583 - val_age_output_acc: 0.3266 - val_bag_output_acc: 0.6007 - val_bodypose_output_acc: 0.7333 - val_emotion_output_acc: 0.6469 - val_footwear_output_acc: 0.5958 - val_gender_output_acc: 0.8001 - val_imagequality_output_acc: 0.4887 - val_weight_output_acc: 0.5604
# Epoch 20/20
# 721/722 [============================>.] - ETA: 0s - loss: 3.2812 - age_output_loss: 0.5213 - bag_output_loss: 0.4568 - bodypose_output_loss: 0.0634 - emotion_output_loss: 0.3782 - footwear_output_loss: 0.2748 - gender_output_loss: 0.1079 - imagequality_output_loss: 0.3545 - weight_output_loss: 0.4400 - age_output_acc: 0.8010 - bag_output_acc: 0.8186 - bodypose_output_acc: 0.9818 - emotion_output_acc: 0.8615 - footwear_output_acc: 0.9002 - gender_output_acc: 0.9638 - imagequality_output_acc: 0.8613 - weight_output_acc: 0.8338Epoch 1/20
# 722/722 [==============================] - 148s 204ms/step - loss: 3.2804 - age_output_loss: 0.5213 - bag_output_loss: 0.4568 - bodypose_output_loss: 0.0634 - emotion_output_loss: 0.3781 - footwear_output_loss: 0.2745 - gender_output_loss: 0.1079 - imagequality_output_loss: 0.3545 - weight_output_loss: 0.4396 - age_output_acc: 0.8009 - bag_output_acc: 0.8186 - bodypose_output_acc: 0.9817 - emotion_output_acc: 0.8615 - footwear_output_acc: 0.9003 - gender_output_acc: 0.9638 - imagequality_output_acc: 0.8613 - weight_output_acc: 0.8340 - val_loss: 12.1977 - val_age_output_loss: 2.5709 - val_bag_output_loss: 1.1091 - val_bodypose_output_loss: 1.0783 - val_emotion_output_loss: 1.4563 - val_footwear_output_loss: 1.4473 - val_gender_output_loss: 0.6383 - val_imagequality_output_loss: 1.7057 - val_weight_output_loss: 1.5154 - val_age_output_acc: 0.3325 - val_bag_output_acc: 0.5958 - val_bodypose_output_acc: 0.7372 - val_emotion_output_acc: 0.6370 - val_footwear_output_acc: 0.5928 - val_gender_output_acc: 0.8030 - val_imagequality_output_acc: 0.4838 - val_weight_output_acc: 0.5540
